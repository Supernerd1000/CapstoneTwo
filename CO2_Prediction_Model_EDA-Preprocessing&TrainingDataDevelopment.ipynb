# %%
#First step is to install the same modules as I used for the Wine Data Projects, because I will use the same techniques.

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns # For all our visualization needs.
import statsmodels.api as sm # What does this do? Find out and type here.
from statsmodels.graphics.api import abline_plot # What does this do? Find out and type here.
from sklearn.metrics import mean_squared_error, r2_score # What does this do? Find out and type here.
from sklearn.model_selection import train_test_split #  What does this do? Find out and type here.
from sklearn import linear_model, preprocessing # What does this do? Find out and type here.
import warnings # For handling error messages.
# Don't worry about the following two instructions: they just suppress warnings that could occur later. 
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %% [markdown]
# # Chapter One:  Additional Data Wrangling and Data Scaling
#
# After I did my first step of Data Wrangling, I needed to do more Data Wrangling in order to further refine my dataset.  The exploratory data analysis stage immediately showed me this, and that really to do this analysis, I had to exclude renewables from my dataase.

# %%
#Then I will import the revised file after my DataWrangling into a dataframe.
df = pd.read_csv('CO2_Prediction_After_Wrangling.csv')

# %%
df.head()
# Out:
#    Data Year Plant state abbreviation                         Utility name  \
# 0       2018                       AK        Alaska Village Elec Coop, Inc
# 1       2018                       AK         Copper Valley Elec Assn, Inc
# 2       2018                       AK        Alaska Village Elec Coop, Inc
# 3       2018                       AK  Anchorage Municipal Light and Power
# 4       2018                       AK        Inside Passage Elec Coop, Inc
#
#             Plant name Plant-level sector           Balancing Authority Name  \
# 0             Alakanuk   Electric Utility               Alaska Miscellaneous
# 1  Allison Creek Hydro   Electric Utility               Alaska Miscellaneous
# 2               Ambler   Electric Utility               Alaska Miscellaneous
# 3          Anchorage 1   Electric Utility  Anchorage Municipal Light & Power
# 4               Angoon   Electric Utility               Alaska Miscellaneous
#
#   eGRID subregion name  Plant latitude  Plant longitude  Number of units  ...  \
# 0   ASCC Miscellaneous       62.683300      -164.654400                5  ...
# 1   ASCC Miscellaneous       61.084444      -146.353333                1  ...
# 2   ASCC Miscellaneous       67.087980      -157.856719                3  ...
# 3     ASCC Alaska Grid       61.222100      -149.866100                8  ...
# 4   ASCC Miscellaneous       57.499166      -134.586140                4  ...
#
#    Plant annual CO2 emissions (tons) Plant annual CH4 emissions (lbs)  \
# 0                              0.000                            0.000
# 1                              0.000                            0.000
# 2                            996.124                           80.676
# 3                          22650.454                          859.171
# 4                           1432.692                          116.034
#
#   Plant annual CO2 total output emission rate (lb/MWh)  \
# 0                                              0.000
# 1                                              0.000
# 2                                           1651.948
# 3                                           1565.501
# 4                                           1733.445
#
#    Plant annual CH4 total output emission rate (lb/MWh)  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.067
# 3                                              0.030
# 4                                              0.070
#
#    Plant unadjusted annual heat input from combustion (MMBtu)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          12197.999
# 3                                         387517.000
# 4                                          17544.000
#
#    Plant nominal heat rate (Btu/kWh)  \
# 0                                NaN
# 1                                NaN
# 2                       10114.427032
# 3                       13391.747590
# 4                       10613.430127
#
#    Plant annual total nonrenewables net generation (MWh)  \
# 0                                                0.0
# 1                                                0.0
# 2                                             1206.0
# 3                                            28937.0
# 4                                             1653.0
#
#    Plant annual total renewables net generation (MWh)  \
# 0                                                0.0
# 1                                            23077.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Plant total nonrenewables generation percent (resource mix)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Plant total renewables generation percent (resource mix)
# 0                                                0.0
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (9123, 28)

# %%
df.dtypes
# Out:
# Data Year                                                                int64
# Plant state abbreviation                                                object
# Utility name                                                            object
# Plant name                                                              object
# Plant-level sector                                                      object
# Balancing Authority Name                                                object
# eGRID subregion name                                                    object
# Plant latitude                                                         float64
# Plant longitude                                                        float64
# Number of units                                                          int64
# Number of generators                                                     int64
# Plant primary fuel                                                      object
# Plant primary coal/oil/gas/ other fossil fuel category                  object
# Flag indicating if the plant burned or generated any amount of coal      int64
# Plant capacity factor                                                  float64
# Plant nameplate capacity (MW)                                          float64
# Nonbaseload Factor                                                     float64
# Plant annual net generation (MWh)                                      float64
# Plant annual CO2 emissions (tons)                                      float64
# Plant annual CH4 emissions (lbs)                                       float64
# Plant annual CO2 total output emission rate (lb/MWh)                   float64
# Plant annual CH4 total output emission rate (lb/MWh)                   float64
# Plant unadjusted annual heat input from combustion (MMBtu)             float64
# Plant nominal heat rate (Btu/kWh)                                      float64
# Plant annual total nonrenewables net generation (MWh)                  float64
# Plant annual total renewables net generation (MWh)                     float64
# Plant total nonrenewables generation percent (resource mix)            float64
# Plant total renewables generation percent (resource mix)               float64
# dtype: object

# %%
#Now I'm curious about the composition of the Plant annual CO2 emmissions (tons) column.  This is going to be our independent variable.
df['Plant annual CO2 emissions (tons)'].value_counts()
# Out:
# 0.000          6052
# 0.001            60
# 0.002            19
# 0.003             7
# 4.573             5
#                ...
# 2814.864          1
# 247811.700        1
# 1561998.200       1
# 860180.300        1
# 118503.720        1
# Name: Plant annual CO2 emissions (tons), Length: 2949, dtype: int64

# %%
# Get a basic statistical summary of the variable 
print(df['Plant annual CO2 emissions (tons)'].describe)

print(df['Plant annual CO2 emissions (tons)'].mean())

print(df['Plant annual CO2 emissions (tons)'].std())

print(df['Plant annual CO2 emissions (tons)'].max())
# Out:
# <bound method NDFrame.describe of 0             0.000
# 1             0.000
# 2           996.124
# 3         22650.454
# 4          1432.692
#            ...
# 9118       2139.344
# 9119     830991.800
# 9120     982289.900
# 9121    1062853.800
# 9122    2988233.100
# Name: Plant annual CO2 emissions (tons), Length: 9123, dtype: float64>
# 215894.06090485587
# 1134127.309376531
# 20155730.7

# %%
#I'm goinng to try to transform this data so that it is easier to map. 

df['Ann CO2 Emissions Million Tons'] = round(df['Plant annual CO2 emissions (tons)'] / 1000000, 2)



df.head()
# Out:
#    Data Year Plant state abbreviation                         Utility name  \
# 0       2018                       AK        Alaska Village Elec Coop, Inc
# 1       2018                       AK         Copper Valley Elec Assn, Inc
# 2       2018                       AK        Alaska Village Elec Coop, Inc
# 3       2018                       AK  Anchorage Municipal Light and Power
# 4       2018                       AK        Inside Passage Elec Coop, Inc
#
#             Plant name Plant-level sector           Balancing Authority Name  \
# 0             Alakanuk   Electric Utility               Alaska Miscellaneous
# 1  Allison Creek Hydro   Electric Utility               Alaska Miscellaneous
# 2               Ambler   Electric Utility               Alaska Miscellaneous
# 3          Anchorage 1   Electric Utility  Anchorage Municipal Light & Power
# 4               Angoon   Electric Utility               Alaska Miscellaneous
#
#   eGRID subregion name  Plant latitude  Plant longitude  Number of units  ...  \
# 0   ASCC Miscellaneous       62.683300      -164.654400                5  ...
# 1   ASCC Miscellaneous       61.084444      -146.353333                1  ...
# 2   ASCC Miscellaneous       67.087980      -157.856719                3  ...
# 3     ASCC Alaska Grid       61.222100      -149.866100                8  ...
# 4   ASCC Miscellaneous       57.499166      -134.586140                4  ...
#
#    Plant annual CH4 emissions (lbs)  \
# 0                             0.000
# 1                             0.000
# 2                            80.676
# 3                           859.171
# 4                           116.034
#
#   Plant annual CO2 total output emission rate (lb/MWh)  \
# 0                                              0.000
# 1                                              0.000
# 2                                           1651.948
# 3                                           1565.501
# 4                                           1733.445
#
#   Plant annual CH4 total output emission rate (lb/MWh)  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.067
# 3                                              0.030
# 4                                              0.070
#
#    Plant unadjusted annual heat input from combustion (MMBtu)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          12197.999
# 3                                         387517.000
# 4                                          17544.000
#
#    Plant nominal heat rate (Btu/kWh)  \
# 0                                NaN
# 1                                NaN
# 2                       10114.427032
# 3                       13391.747590
# 4                       10613.430127
#
#    Plant annual total nonrenewables net generation (MWh)  \
# 0                                                0.0
# 1                                                0.0
# 2                                             1206.0
# 3                                            28937.0
# 4                                             1653.0
#
#    Plant annual total renewables net generation (MWh)  \
# 0                                                0.0
# 1                                            23077.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Plant total nonrenewables generation percent (resource mix)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Plant total renewables generation percent (resource mix)  \
# 0                                                0.0
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Ann CO2 Emissions Million Tons
# 0                            0.00
# 1                            0.00
# 2                            0.00
# 3                            0.02
# 4                            0.00
#
# [5 rows x 29 columns]

# %%
plt.hist(df['Ann CO2 Emissions Million Tons'], bins=30)
# Out:
# (array([8.586e+03, 1.640e+02, 1.160e+02, 5.800e+01, 4.200e+01, 2.200e+01,
#         1.700e+01, 1.000e+01, 2.300e+01, 1.400e+01, 6.000e+00, 1.300e+01,
#         1.100e+01, 6.000e+00, 1.000e+00, 8.000e+00, 3.000e+00, 4.000e+00,
#         2.000e+00, 5.000e+00, 1.000e+00, 2.000e+00, 1.000e+00, 2.000e+00,
#         2.000e+00, 0.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 0.   ,  0.672,  1.344,  2.016,  2.688,  3.36 ,  4.032,  4.704,
#          5.376,  6.048,  6.72 ,  7.392,  8.064,  8.736,  9.408, 10.08 ,
#         10.752, 11.424, 12.096, 12.768, 13.44 , 14.112, 14.784, 15.456,
#         16.128, 16.8  , 17.472, 18.144, 18.816, 19.488, 20.16 ]),
#  <a list of 30 Patch objects>)

# %%
#I would like to get a better idea of the plants with significant CO2 pollution.   How about the ones that are above 5 million tons a year

Dfmorethanton = df[df['Ann CO2 Emissions Million Tons'] >= 5]

Dflessthanton = df[df['Ann CO2 Emissions Million Tons'] <= 5]

# %%
plt.hist(Dfmorethanton['Ann CO2 Emissions Million Tons'], bins = 30)
# Out:
# (array([13., 18., 14.,  3.,  4., 13.,  7.,  6.,  4.,  1.,  4.,  6.,  1.,
#          4.,  1.,  2.,  4.,  1.,  1.,  1.,  1.,  2.,  2.,  0.,  0.,  2.,
#          1.,  0.,  0.,  1.]),
#  array([ 5.01 ,  5.515,  6.02 ,  6.525,  7.03 ,  7.535,  8.04 ,  8.545,
#          9.05 ,  9.555, 10.06 , 10.565, 11.07 , 11.575, 12.08 , 12.585,
#         13.09 , 13.595, 14.1  , 14.605, 15.11 , 15.615, 16.12 , 16.625,
#         17.13 , 17.635, 18.14 , 18.645, 19.15 , 19.655, 20.16 ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(Dflessthanton['Ann CO2 Emissions Million Tons'])
# Out:
# (array([8.515e+03, 1.630e+02, 9.300e+01, 9.300e+01, 4.200e+01, 4.000e+01,
#         2.300e+01, 1.400e+01, 1.500e+01, 8.000e+00]),
#  array([0.   , 0.496, 0.992, 1.488, 1.984, 2.48 , 2.976, 3.472, 3.968,
#         4.464, 4.96 ]),
#  <a list of 10 Patch objects>)

# %%
#This is a clear opportunity to use one of the Scaling features in python to scale this data.

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data = df[['Plant annual CO2 emissions (tons)']]

scaler.fit(data)

data_scaled = scaler.transform(data)

plt.hist(data_scaled)
# Out:
# (array([8.866e+03, 1.210e+02, 5.100e+01, 3.300e+01, 1.800e+01, 1.500e+01,
#         8.000e+00, 5.000e+00, 4.000e+00, 2.000e+00]),
#  array([-0.19037183,  1.58692736,  3.36422654,  5.14152573,  6.91882492,
#          8.69612411, 10.47342329, 12.25072248, 14.02802167, 15.80532086,
#         17.58262004]),
#  <a list of 10 Patch objects>)

# %%
#Looks like there are mostly plants that don't emit alot.  There are only a few that have really large emissions.
#How many plants are there in each state?

df['Plant state abbreviation'].value_counts()
# Out:
# CA    1390
# NC     677
# NY     476
# TX     459
# MN     451
# MA     402
# NJ     281
# IA     249
# MI     232
# PA     223
# IL     202
# WI     191
# OR     190
# CO     190
# FL     175
# OH     173
# GA     158
# IN     156
# VA     153
# AK     143
# KS     141
# ID     138
# WA     137
# SC     134
# AZ     128
# MO     125
# CT     114
# MD     114
# OK     110
# NE     108
# NM     107
# UT     103
# ME      99
# VT      94
# NV      83
# LA      78
# AL      77
# TN      72
# WY      63
# MT      60
# NH      59
# AR      58
# HI      58
# ND      55
# KY      51
# RI      43
# MS      43
# SD      36
# WV      34
# DE      28
# DC       2
# Name: Plant state abbreviation, dtype: int64

# %%
#Which states are the worst emitors?

statetotals = df.groupby('Plant state abbreviation')['Ann CO2 Emissions Million Tons'].sum()

print(statetotals)
# Out:
# Plant state abbreviation
# AK      2.73
# AL     61.88
# AR     41.18
# AZ     53.98
# CA     40.96
# CO     37.71
# CT      9.98
# DC      0.02
# DE      2.80
# FL    114.81
# GA     59.40
# HI      7.41
# IA     33.78
# ID      1.46
# IL     76.43
# IN     98.52
# KS     25.54
# KY     71.82
# LA     40.45
# MA      9.81
# MD     18.28
# ME      1.46
# MI     64.12
# MN     30.53
# MO     69.09
# MS     29.08
# MT     16.30
# NC     53.61
# ND     32.08
# NE     25.99
# NH      2.55
# NJ     18.72
# NM     21.66
# NV     14.76
# NY     27.59
# OH     83.37
# OK     38.38
# OR     10.00
# PA     84.40
# RI      3.63
# SC     31.30
# SD      3.27
# TN     30.31
# TX    231.59
# UT     31.46
# VA     34.95
# VT      0.04
# WA     11.61
# WI     45.62
# WV     65.42
# WY     47.23
# Name: Ann CO2 Emissions Million Tons, dtype: float64

# %%
#That's interesting.  I want to see a bar chart of these totals.

statetotals.plot.bar(x='Plant state abbreviation', y='Ann CO2 Emissions Million Tons', rot=0)

# %%
#Now I will explore number of units
plt.hist(df['Number of units'], bins = 30, range=[0,20])
# Out:
# (array([0.000e+00, 4.799e+03, 0.000e+00, 1.538e+03, 9.020e+02, 0.000e+00,
#         6.530e+02, 3.480e+02, 0.000e+00, 2.630e+02, 1.480e+02, 0.000e+00,
#         1.520e+02, 6.600e+01, 0.000e+00, 5.700e+01, 3.500e+01, 0.000e+00,
#         5.800e+01, 1.600e+01, 0.000e+00, 1.200e+01, 1.000e+01, 0.000e+00,
#         1.200e+01, 4.000e+00, 0.000e+00, 1.000e+01, 3.000e+00, 5.000e+00]),
#  array([ 0.        ,  0.66666667,  1.33333333,  2.        ,  2.66666667,
#          3.33333333,  4.        ,  4.66666667,  5.33333333,  6.        ,
#          6.66666667,  7.33333333,  8.        ,  8.66666667,  9.33333333,
#         10.        , 10.66666667, 11.33333333, 12.        , 12.66666667,
#         13.33333333, 14.        , 14.66666667, 15.33333333, 16.        ,
#         16.66666667, 17.33333333, 18.        , 18.66666667, 19.33333333,
#         20.        ]),
#  <a list of 30 Patch objects>)

# %%
#Let's do a value_counts() on units

df['Number of units'].value_counts()
# Out:
# 1     4799
# 2     1538
# 3      902
# 4      653
# 5      348
# 6      263
# 8      152
# 7      148
# 9       66
# 12      58
# 10      57
# 11      35
# 13      16
# 14      12
# 16      12
# 18      10
# 15      10
# 20       5
# 48       4
# 17       4
# 21       4
# 22       4
# 24       3
# 19       3
# 36       3
# 27       2
# 32       2
# 31       2
# 34       1
# 73       1
# 41       1
# 33       1
# 23       1
# 35       1
# 28       1
# 29       1
# Name: Number of units, dtype: int64

# %%
#Now I want to see by category how these values shake out.
df.groupby('Plant primary coal/oil/gas/ other fossil fuel category')['Ann CO2 Emissions Million Tons'].count()
# Out:
# Plant primary coal/oil/gas/ other fossil fuel category
# BIOMASS        710
# COAL           345
# GAS           1708
# GEOTHERMAL      64
# HYDRO         1448
# NUCLEAR         61
# OFSL            19
# OIL            819
# OTHF           127
# SOLAR         2719
# WIND          1103
# Name: Ann CO2 Emissions Million Tons, dtype: int64

# %%
df.groupby('Plant primary coal/oil/gas/ other fossil fuel category')['Ann CO2 Emissions Million Tons'].sum()
# Out:
# Plant primary coal/oil/gas/ other fossil fuel category
# BIOMASS         17.38
# COAL          1301.56
# GAS            623.22
# GEOTHERMAL       1.20
# HYDRO            0.00
# NUCLEAR          2.50
# OFSL             4.18
# OIL             15.70
# OTHF             3.25
# SOLAR            0.08
# WIND             0.00
# Name: Ann CO2 Emissions Million Tons, dtype: float64

# %%
#It's clear from these numbers that I should really only be looking at coal and gas emissions.   I'm going to make a new dataframe that is just Coal and Gas.  Also only the plants that have energy production (MWh) greater than 0.

dfCOAL = df[df['Plant primary coal/oil/gas/ other fossil fuel category']=='COAL']
dfGAS = df[df['Plant primary coal/oil/gas/ other fossil fuel category']=='GAS']

df = dfCOAL.append(dfGAS)

df = df[df['Plant annual net generation (MWh)']>0]

# %%
#I'm just going to get rid of anything where the plant had any renewable generation at all.

df = df[df['Plant total renewables generation percent (resource mix)']==0]

# %%
#I should have done this from the beginning.  Now I will restart exploratory analysis

df.shape
# Out:
# (1860, 29)

# %% [markdown]
# # Chapter 2:  Exploratory Data Analysis
#
# After discovering that I needed to get rid of my renewables data before really analyzing CO2 Emissions, I started Exploratory Data Analysis all over again-This time only looking at Natural Gas and Coal Plants.   You can see my research where I looked at both of these types of plant by State, then the CO2 Emissions by State.  Finally I started looking at the Plant Annual MWh generation statistics.

# %%
df.dtypes
# Out:
# Data Year                                                                int64
# Plant state abbreviation                                                object
# Utility name                                                            object
# Plant name                                                              object
# Plant-level sector                                                      object
# Balancing Authority Name                                                object
# eGRID subregion name                                                    object
# Plant latitude                                                         float64
# Plant longitude                                                        float64
# Number of units                                                          int64
# Number of generators                                                     int64
# Plant primary fuel                                                      object
# Plant primary coal/oil/gas/ other fossil fuel category                  object
# Flag indicating if the plant burned or generated any amount of coal      int64
# Plant capacity factor                                                  float64
# Plant nameplate capacity (MW)                                          float64
# Nonbaseload Factor                                                     float64
# Plant annual net generation (MWh)                                      float64
# Plant annual CO2 emissions (tons)                                      float64
# Plant annual CH4 emissions (lbs)                                       float64
# Plant annual CO2 total output emission rate (lb/MWh)                   float64
# Plant annual CH4 total output emission rate (lb/MWh)                   float64
# Plant unadjusted annual heat input from combustion (MMBtu)             float64
# Plant nominal heat rate (Btu/kWh)                                      float64
# Plant annual total nonrenewables net generation (MWh)                  float64
# Plant annual total renewables net generation (MWh)                     float64
# Plant total nonrenewables generation percent (resource mix)            float64
# Plant total renewables generation percent (resource mix)               float64
# Ann CO2 Emissions Million Tons                                         float64
# dtype: object

# %%
df['Plant state abbreviation'].value_counts()
# Out:
# CA    257
# TX    175
# NY     88
# IL     81
# PA     76
# MI     66
# FL     65
# OH     54
# KS     52
# LA     48
# IN     45
# NJ     43
# CT     40
# MO     40
# WI     40
# IA     39
# NE     34
# VA     34
# MN     34
# CO     34
# MA     33
# AZ     31
# GA     31
# OK     31
# MS     27
# AL     27
# UT     26
# NC     26
# MD     23
# AR     22
# SC     22
# KY     21
# NM     20
# WY     19
# NV     17
# WA     17
# AK     16
# TN     15
# WV     14
# OR     13
# MT     11
# ND      9
# RI      9
# ID      8
# SD      8
# DE      7
# ME      6
# NH      4
# DC      1
# HI      1
# Name: Plant state abbreviation, dtype: int64

# %%
bystate = df.groupby('Plant state abbreviation')['Ann CO2 Emissions Million Tons'].sum()
print(bystate)
# Out:
# Plant state abbreviation
# AK      2.17
# AL     61.27
# AR     41.05
# AZ     43.11
# CA     36.94
# CO     37.71
# CT      8.88
# DC      0.02
# DE      0.95
# FL     92.28
# GA     58.89
# HI      1.55
# IA     33.08
# ID      1.45
# IL     76.42
# IN     97.53
# KS     25.54
# KY     69.00
# LA     38.46
# MA      8.06
# MD     17.76
# ME      0.89
# MI     63.10
# MN     28.98
# MO     67.43
# MS     28.71
# MT     15.91
# NC     53.05
# ND     32.06
# NE     25.88
# NH      2.03
# NJ     17.41
# NM     21.63
# NV     14.51
# NY     23.57
# OH     81.47
# OK     35.30
# OR      9.89
# PA     81.70
# RI      3.63
# SC     30.95
# SD      3.27
# TN     29.51
# TX    229.28
# UT     31.42
# VA     29.31
# WA     11.36
# WI     45.21
# WV     65.42
# WY     46.93
# Name: Ann CO2 Emissions Million Tons, dtype: float64

# %%
df.head()
# Out:
#      Data Year Plant state abbreviation                      Utility name  \
# 8         2018                       AK                 Aurora Energy LLC
# 28        2018                       AK         U S Air Force-Eielson AFB
# 49        2018                       AK       Golden Valley Elec Assn Inc
# 133       2018                       AK              University of Alaska
# 135       2018                       AK  Doyon Utilities - Ft. Wainwright
#
#                                  Plant name Plant-level sector  \
# 8                   Aurora Energy LLC Chena            IPP CHP
# 28   Eielson AFB Central Heat & Power Plant     Commercial CHP
# 49                                    Healy   Electric Utility
# 133          University of Alaska Fairbanks     Commercial CHP
# 135                  Utility Plants Section   Electric Utility
#
#     Balancing Authority Name eGRID subregion name  Plant latitude  \
# 8       Alaska Miscellaneous     ASCC Alaska Grid       64.847743
# 28      Alaska Miscellaneous     ASCC Alaska Grid       64.671410
# 49      Alaska Miscellaneous     ASCC Alaska Grid       63.854200
# 133     Alaska Miscellaneous     ASCC Alaska Grid       64.854171
# 135     Alaska Miscellaneous     ASCC Alaska Grid       64.825601
#
#      Plant longitude  Number of units  ...  Plant annual CH4 emissions (lbs)  \
# 8        -147.735063                4  ...                         39367.557
# 28       -147.075988               12  ...                          9125.616
# 49       -148.950000                3  ...                         90442.723
# 133      -147.822075                6  ...                          5199.367
# 135      -147.648627                6  ...                         13526.302
#
#     Plant annual CO2 total output emission rate (lb/MWh)  \
# 8                                             1952.669
# 28                                            1188.374
# 49                                            3041.630
# 133                                           1188.837
# 135                                           1322.975
#
#     Plant annual CH4 total output emission rate (lb/MWh)  \
# 8                                                0.221
# 28                                               0.135
# 49                                               0.345
# 133                                              0.125
# 135                                              0.150
#
#      Plant unadjusted annual heat input from combustion (MMBtu)  \
# 8                                          3270570.300
# 28                                         2531566.983
# 49                                         3787280.400
# 133                                        1192968.300
# 135                                        3398927.058
#
#      Plant nominal heat rate (Btu/kWh)  \
# 8                          9129.209435
# 28                         5556.757950
# 49                        14429.658867
# 133                        5755.087741
# 135                        6185.233963
#
#      Plant annual total nonrenewables net generation (MWh)  \
# 8                                           177819.000
# 28                                           67750.000
# 49                                          262464.999
# 133                                          41638.000
# 135                                          90177.000
#
#      Plant annual total renewables net generation (MWh)  \
# 8                                                  0.0
# 28                                                 0.0
# 49                                                 0.0
# 133                                                0.0
# 135                                                0.0
#
#      Plant total nonrenewables generation percent (resource mix)  \
# 8                                                  1.0
# 28                                                 1.0
# 49                                                 1.0
# 133                                                1.0
# 135                                                1.0
#
#      Plant total renewables generation percent (resource mix)  \
# 8                                                  0.0
# 28                                                 0.0
# 49                                                 0.0
# 133                                                0.0
# 135                                                0.0
#
#      Ann CO2 Emissions Million Tons
# 8                              0.17
# 28                             0.04
# 49                             0.40
# 133                            0.02
# 135                            0.06
#
# [5 rows x 29 columns]

# %%
#What is the distribution of generation amongst all these plants?

df['Plant annual net generation (MWh)'].value_counts()
# Out:
# 30.0        3
# 62.0        3
# 13.0        3
# 720.0       2
# 8434.0      2
#            ..
# 22110.0     1
# 44177.0     1
# 425306.0    1
# 547512.0    1
# 144.0       1
# Name: Plant annual net generation (MWh), Length: 1840, dtype: int64

# %%
plt.hist(df['Plant annual net generation (MWh)'],bins=30)
# Out:
# (array([1.236e+03, 1.320e+02, 8.100e+01, 7.000e+01, 6.500e+01, 4.900e+01,
#         4.400e+01, 4.300e+01, 3.200e+01, 1.100e+01, 1.700e+01, 1.600e+01,
#         9.000e+00, 1.000e+01, 9.000e+00, 8.000e+00, 3.000e+00, 5.000e+00,
#         4.000e+00, 3.000e+00, 3.000e+00, 1.000e+00, 0.000e+00, 3.000e+00,
#         2.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([1.00000000e+00, 6.61364767e+05, 1.32272853e+06, 1.98409230e+06,
#         2.64545607e+06, 3.30681983e+06, 3.96818360e+06, 4.62954737e+06,
#         5.29091113e+06, 5.95227490e+06, 6.61363867e+06, 7.27500243e+06,
#         7.93636620e+06, 8.59772997e+06, 9.25909373e+06, 9.92045750e+06,
#         1.05818213e+07, 1.12431850e+07, 1.19045488e+07, 1.25659126e+07,
#         1.32272763e+07, 1.38886401e+07, 1.45500039e+07, 1.52113676e+07,
#         1.58727314e+07, 1.65340952e+07, 1.71954589e+07, 1.78568227e+07,
#         1.85181865e+07, 1.91795502e+07, 1.98409140e+07]),
#  <a list of 30 Patch objects>)

# %%
Dflarge = df[df['Plant annual net generation (MWh)'] >= 1000000]

# %%
plt.hist(Dflarge['Plant annual net generation (MWh)'],bins=30)
# Out:
# (array([91., 73., 55., 50., 55., 43., 39., 26., 13., 15., 14., 10.,  9.,
#          9.,  7.,  5.,  3.,  4.,  3.,  4.,  2.,  0.,  1.,  3.,  1.,  1.,
#          1.,  1.,  0.,  1.]),
#  array([ 1003780.        ,  1631684.46666667,  2259588.93333333,
#          2887493.4       ,  3515397.86666667,  4143302.33333333,
#          4771206.8       ,  5399111.26666667,  6027015.73333333,
#          6654920.2       ,  7282824.66666667,  7910729.13333333,
#          8538633.6       ,  9166538.06666667,  9794442.53333333,
#         10422347.        , 11050251.46666667, 11678155.93333333,
#         12306060.4       , 12933964.86666667, 13561869.33333333,
#         14189773.8       , 14817678.26666667, 15445582.73333333,
#         16073487.2       , 16701391.66666667, 17329296.13333333,
#         17957200.6       , 18585105.06666667, 19213009.53333334,
#         19840914.        ]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# # Chapter 3: Coal and Gas models.
#
# I quickly started to see that the differences between Coal and Gas Emissions seemed pretty significant.  I started running scatter plots to visualize these differences.   Then I started to create regression models to predict Coal CO2 emissions and Gas CO2 emissions seperately.  First I made a simple regression, then I turned it into a multiple regression.  I also then did a little research of how Gas plants' Methane emissions relate to their CO2 emissions, and I did the same for coal.

# %%
#plt.scatter(df['Plant annual net generation (MWh)'], df['Ann CO2 Emissions Million Tons'])


sns.lmplot(x='Plant annual net generation (MWh)', y='Ann CO2 Emissions Million Tons', data=df, hue='Plant primary coal/oil/gas/ other fossil fuel category',palette='Set1')

# %%
#This must be the effect of gas vs natural gas.  Let's plot those seperately
dfCOAL = df[df['Plant primary coal/oil/gas/ other fossil fuel category']=='COAL']
dfGAS = df[df['Plant primary coal/oil/gas/ other fossil fuel category']=='GAS']

# %%
plt.scatter(dfCOAL['Plant annual net generation (MWh)'], dfCOAL['Ann CO2 Emissions Million Tons'])

# %%
plt.scatter(dfGAS['Plant annual net generation (MWh)'], dfGAS['Ann CO2 Emissions Million Tons'])

# %%
#As expected this is a very direct relationship in both cases.  This seems to be a direct linear relationship.

sns.regplot('Plant annual net generation (MWh)', 'Ann CO2 Emissions Million Tons', data=dfCOAL)

# %%
sns.regplot('Plant annual net generation (MWh)', 'Ann CO2 Emissions Million Tons', data=dfGAS)

# %%
#This is something maybe I can come back to as something to test to see if there is a significant difference between the COAL and GAS emissions.
#First, I'm going to build a linear model between Annual Emissions and Power Generation for Coal and Gas

y = dfCOAL[['Ann CO2 Emissions Million Tons']]
X = dfCOAL[['Plant annual net generation (MWh)']]

scaler.fit(y)

y = scaler.transform(y)


scaler.fit(X)

X = scaler.transform(X)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
print(X_train.shape)

print(X_test.shape)

print(y_train.shape)

print(y_test.shape)
# Out:
# (237, 1)
# (79, 1)
# (237, 1)
# (79, 1)

# %%
rModel = linear_model.LinearRegression(normalize=True)

# %%
# We now want to train the model on our test data.
rModel.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
# Evaluate the model  
print(rModel.score(X_train,y_train))
# Out:
# 0.9819393289548926

# %%
# Use the model to make predictions about our test data
y_pred = rModel.predict(X_test)

# %%
# Let's plot the predictions against the actual result. Use scatter()
plt.scatter(y_test,y_pred)

# %%
#Now I"m goinig to make a GAS Model using the OLS Method.

X = dfGAS[['Plant annual net generation (MWh)']]

# %%
X = sm.add_constant(X)

# %%
y = dfGAS[['Ann CO2 Emissions Million Tons']]
X = dfGAS[['Plant annual net generation (MWh)']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
# Create the model
rModel2 = sm.OLS(y_train,X_train)

# Fit the model with fit() 
rModel2_results = rModel2.fit()

# %%
# Evaluate the model with .summary()
print(rModel2_results.summary())
# Out:
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Ann CO2 Emissions Million Tons   R-squared (uncentered):                   0.984
# Model:                                        OLS   Adj. R-squared (uncentered):              0.984
# Method:                             Least Squares   F-statistic:                          7.294e+04
# Date:                            Wed, 05 Aug 2020   Prob (F-statistic):                        0.00
# Time:                                    16:01:23   Log-Likelihood:                          863.52
# No. Observations:                            1158   AIC:                                     -1725.
# Df Residuals:                                1157   BIC:                                     -1720.
# Df Model:                                       1
# Covariance Type:                        nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Plant annual net generation (MWh)  4.281e-07   1.59e-09    270.076      0.000    4.25e-07    4.31e-07
# ==============================================================================
# Omnibus:                      474.087   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11020.884
# Skew:                           1.340   Prob(JB):                         0.00
# Kurtosis:                      17.874   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Let's use our new model to make predictions of the dependent variable y. Use predict(), and plug in X_test as the parameter
y_pred = rModel2_results.predict(X_test)

# %%
# Plot the predictions
# Build a scatterplot
plt.scatter(y_test, y_pred)

# Add a line for perfect correlation. Can you see what this line is doing? Use plot()
plt.plot([x for x in range(0,15)],[x for x in range(0,15)], color='red')

# Label it nicely
plt.title("Model 2 predictions vs. the actual values")
plt.xlabel("Energy Created - Natural Gas")
plt.ylabel("CO2 Generated - Natural Gas")
# Out:
# Text(0, 0.5, 'CO2 Generated - Natural Gas')

# %%
#These are very accurate models, but they are no surprise.  Let's investigate some factors that aren't as obvious. 
dfGAS.corr()
# Out:
#                                                     Data Year  Plant latitude  \
# Data Year                                                 NaN             NaN
# Plant latitude                                            NaN        1.000000
# Plant longitude                                           NaN        0.065375
# Number of units                                           NaN       -0.006455
# Number of generators                                      NaN       -0.083862
# Flag indicating if the plant burned or generate...        NaN       -0.015647
# Plant capacity factor                                     NaN       -0.135340
# Plant nameplate capacity (MW)                             NaN       -0.229976
# Nonbaseload Factor                                        NaN        0.120035
# Plant annual net generation (MWh)                         NaN       -0.202163
# Plant annual CO2 emissions (tons)                         NaN       -0.204468
# Plant annual CH4 emissions (lbs)                          NaN       -0.204923
# Plant annual CO2 total output emission rate (lb...        NaN        0.022984
# Plant annual CH4 total output emission rate (lb...        NaN        0.032479
# Plant unadjusted annual heat input from combust...        NaN       -0.228417
# Plant nominal heat rate (Btu/kWh)                         NaN        0.021707
# Plant annual total nonrenewables net generation...        NaN       -0.202163
# Plant annual total renewables net generation (MWh)        NaN             NaN
# Plant total nonrenewables generation percent (r...        NaN             NaN
# Plant total renewables generation percent (reso...        NaN             NaN
# Ann CO2 Emissions Million Tons                            NaN       -0.204540
#
#                                                     Plant longitude  \
# Data Year                                                       NaN
# Plant latitude                                             0.065375
# Plant longitude                                            1.000000
# Number of units                                            0.055648
# Number of generators                                       0.099375
# Flag indicating if the plant burned or generate...        -0.028960
# Plant capacity factor                                     -0.044196
# Plant nameplate capacity (MW)                              0.131185
# Nonbaseload Factor                                         0.051187
# Plant annual net generation (MWh)                          0.121955
# Plant annual CO2 emissions (tons)                          0.122064
# Plant annual CH4 emissions (lbs)                           0.124381
# Plant annual CO2 total output emission rate (lb...        -0.023235
# Plant annual CH4 total output emission rate (lb...        -0.018180
# Plant unadjusted annual heat input from combust...         0.117574
# Plant nominal heat rate (Btu/kWh)                         -0.033334
# Plant annual total nonrenewables net generation...         0.121955
# Plant annual total renewables net generation (MWh)              NaN
# Plant total nonrenewables generation percent (r...              NaN
# Plant total renewables generation percent (reso...              NaN
# Ann CO2 Emissions Million Tons                             0.122080
#
#                                                     Number of units  \
# Data Year                                                       NaN
# Plant latitude                                            -0.006455
# Plant longitude                                            0.055648
# Number of units                                            1.000000
# Number of generators                                       0.790261
# Flag indicating if the plant burned or generate...        -0.063320
# Plant capacity factor                                     -0.178015
# Plant nameplate capacity (MW)                              0.253035
# Nonbaseload Factor                                         0.188074
# Plant annual net generation (MWh)                          0.111673
# Plant annual CO2 emissions (tons)                          0.125615
# Plant annual CH4 emissions (lbs)                           0.125413
# Plant annual CO2 total output emission rate (lb...         0.020447
# Plant annual CH4 total output emission rate (lb...         0.015867
# Plant unadjusted annual heat input from combust...         0.143994
# Plant nominal heat rate (Btu/kWh)                          0.012323
# Plant annual total nonrenewables net generation...         0.111673
# Plant annual total renewables net generation (MWh)              NaN
# Plant total nonrenewables generation percent (r...              NaN
# Plant total renewables generation percent (reso...              NaN
# Ann CO2 Emissions Million Tons                             0.125649
#
#                                                     Number of generators  \
# Data Year                                                            NaN
# Plant latitude                                                 -0.083862
# Plant longitude                                                 0.099375
# Number of units                                                 0.790261
# Number of generators                                            1.000000
# Flag indicating if the plant burned or generate...             -0.104628
# Plant capacity factor                                          -0.174554
# Plant nameplate capacity (MW)                                   0.520121
# Nonbaseload Factor                                              0.200867
# Plant annual net generation (MWh)                               0.291088
# Plant annual CO2 emissions (tons)                               0.308544
# Plant annual CH4 emissions (lbs)                                0.317192
# Plant annual CO2 total output emission rate (lb...              0.011302
# Plant annual CH4 total output emission rate (lb...              0.014221
# Plant unadjusted annual heat input from combust...              0.306366
# Plant nominal heat rate (Btu/kWh)                               0.001422
# Plant annual total nonrenewables net generation...              0.291088
# Plant annual total renewables net generation (MWh)                   NaN
# Plant total nonrenewables generation percent (r...                   NaN
# Plant total renewables generation percent (reso...                   NaN
# Ann CO2 Emissions Million Tons                                  0.308584
#
#                                                     Flag indicating if the plant burned or generated any amount of coal  \
# Data Year                                                                                         NaN
# Plant latitude                                                                              -0.015647
# Plant longitude                                                                             -0.028960
# Number of units                                                                             -0.063320
# Number of generators                                                                        -0.104628
# Flag indicating if the plant burned or generate...                                           1.000000
# Plant capacity factor                                                                        0.007985
# Plant nameplate capacity (MW)                                                               -0.052317
# Nonbaseload Factor                                                                          -0.029044
# Plant annual net generation (MWh)                                                           -0.016533
# Plant annual CO2 emissions (tons)                                                           -0.030471
# Plant annual CH4 emissions (lbs)                                                            -0.118053
# Plant annual CO2 total output emission rate (lb...                                           0.009639
# Plant annual CH4 total output emission rate (lb...                                          -0.030497
# Plant unadjusted annual heat input from combust...                                          -0.025340
# Plant nominal heat rate (Btu/kWh)                                                            0.014806
# Plant annual total nonrenewables net generation...                                          -0.016533
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                              -0.030738
#
#                                                     Plant capacity factor  \
# Data Year                                                             NaN
# Plant latitude                                                  -0.135340
# Plant longitude                                                 -0.044196
# Number of units                                                 -0.178015
# Number of generators                                            -0.174554
# Flag indicating if the plant burned or generate...               0.007985
# Plant capacity factor                                            1.000000
# Plant nameplate capacity (MW)                                    0.026560
# Nonbaseload Factor                                              -0.973346
# Plant annual net generation (MWh)                                0.355616
# Plant annual CO2 emissions (tons)                                0.329665
# Plant annual CH4 emissions (lbs)                                 0.317039
# Plant annual CO2 total output emission rate (lb...              -0.158044
# Plant annual CH4 total output emission rate (lb...              -0.138050
# Plant unadjusted annual heat input from combust...               0.367304
# Plant nominal heat rate (Btu/kWh)                               -0.142250
# Plant annual total nonrenewables net generation...               0.355616
# Plant annual total renewables net generation (MWh)                    NaN
# Plant total nonrenewables generation percent (r...                    NaN
# Plant total renewables generation percent (reso...                    NaN
# Ann CO2 Emissions Million Tons                                   0.329751
#
#                                                     Plant nameplate capacity (MW)  \
# Data Year                                                                     NaN
# Plant latitude                                                          -0.229976
# Plant longitude                                                          0.131185
# Number of units                                                          0.253035
# Number of generators                                                     0.520121
# Flag indicating if the plant burned or generate...                      -0.052317
# Plant capacity factor                                                    0.026560
# Plant nameplate capacity (MW)                                            1.000000
# Nonbaseload Factor                                                       0.022615
# Plant annual net generation (MWh)                                        0.759671
# Plant annual CO2 emissions (tons)                                        0.785383
# Plant annual CH4 emissions (lbs)                                         0.783897
# Plant annual CO2 total output emission rate (lb...                      -0.038126
# Plant annual CH4 total output emission rate (lb...                      -0.041832
# Plant unadjusted annual heat input from combust...                       0.758117
# Plant nominal heat rate (Btu/kWh)                                       -0.044708
# Plant annual total nonrenewables net generation...                       0.759671
# Plant annual total renewables net generation (MWh)                            NaN
# Plant total nonrenewables generation percent (r...                            NaN
# Plant total renewables generation percent (reso...                            NaN
# Ann CO2 Emissions Million Tons                                           0.785426
#
#                                                     Nonbaseload Factor  \
# Data Year                                                          NaN
# Plant latitude                                                0.120035
# Plant longitude                                               0.051187
# Number of units                                               0.188074
# Number of generators                                          0.200867
# Flag indicating if the plant burned or generate...           -0.029044
# Plant capacity factor                                        -0.973346
# Plant nameplate capacity (MW)                                 0.022615
# Nonbaseload Factor                                            1.000000
# Plant annual net generation (MWh)                            -0.313770
# Plant annual CO2 emissions (tons)                            -0.282086
# Plant annual CH4 emissions (lbs)                             -0.268019
# Plant annual CO2 total output emission rate (lb...            0.130167
# Plant annual CH4 total output emission rate (lb...            0.108917
# Plant unadjusted annual heat input from combust...           -0.321257
# Plant nominal heat rate (Btu/kWh)                             0.113756
# Plant annual total nonrenewables net generation...           -0.313770
# Plant annual total renewables net generation (MWh)                 NaN
# Plant total nonrenewables generation percent (r...                 NaN
# Plant total renewables generation percent (reso...                 NaN
# Ann CO2 Emissions Million Tons                               -0.282161
#
#                                                     Plant annual net generation (MWh)  \
# Data Year                                                                         NaN
# Plant latitude                                                              -0.202163
# Plant longitude                                                              0.121955
# Number of units                                                              0.111673
# Number of generators                                                         0.291088
# Flag indicating if the plant burned or generate...                          -0.016533
# Plant capacity factor                                                        0.355616
# Plant nameplate capacity (MW)                                                0.759671
# Nonbaseload Factor                                                          -0.313770
# Plant annual net generation (MWh)                                            1.000000
# Plant annual CO2 emissions (tons)                                            0.989921
# Plant annual CH4 emissions (lbs)                                             0.967043
# Plant annual CO2 total output emission rate (lb...                          -0.065455
# Plant annual CH4 total output emission rate (lb...                          -0.067893
# Plant unadjusted annual heat input from combust...                           0.981271
# Plant nominal heat rate (Btu/kWh)                                           -0.068990
# Plant annual total nonrenewables net generation...                           1.000000
# Plant annual total renewables net generation (MWh)                                NaN
# Plant total nonrenewables generation percent (r...                                NaN
# Plant total renewables generation percent (reso...                                NaN
# Ann CO2 Emissions Million Tons                                               0.989928
#
#                                                     ...  \
# Data Year                                           ...
# Plant latitude                                      ...
# Plant longitude                                     ...
# Number of units                                     ...
# Number of generators                                ...
# Flag indicating if the plant burned or generate...  ...
# Plant capacity factor                               ...
# Plant nameplate capacity (MW)                       ...
# Nonbaseload Factor                                  ...
# Plant annual net generation (MWh)                   ...
# Plant annual CO2 emissions (tons)                   ...
# Plant annual CH4 emissions (lbs)                    ...
# Plant annual CO2 total output emission rate (lb...  ...
# Plant annual CH4 total output emission rate (lb...  ...
# Plant unadjusted annual heat input from combust...  ...
# Plant nominal heat rate (Btu/kWh)                   ...
# Plant annual total nonrenewables net generation...  ...
# Plant annual total renewables net generation (MWh)  ...
# Plant total nonrenewables generation percent (r...  ...
# Plant total renewables generation percent (reso...  ...
# Ann CO2 Emissions Million Tons                      ...
#
#                                                     Plant annual CH4 emissions (lbs)  \
# Data Year                                                                        NaN
# Plant latitude                                                             -0.204923
# Plant longitude                                                             0.124381
# Number of units                                                             0.125413
# Number of generators                                                        0.317192
# Flag indicating if the plant burned or generate...                         -0.118053
# Plant capacity factor                                                       0.317039
# Plant nameplate capacity (MW)                                               0.783897
# Nonbaseload Factor                                                         -0.268019
# Plant annual net generation (MWh)                                           0.967043
# Plant annual CO2 emissions (tons)                                           0.974726
# Plant annual CH4 emissions (lbs)                                            1.000000
# Plant annual CO2 total output emission rate (lb...                         -0.060540
# Plant annual CH4 total output emission rate (lb...                         -0.056887
# Plant unadjusted annual heat input from combust...                          0.953328
# Plant nominal heat rate (Btu/kWh)                                          -0.065008
# Plant annual total nonrenewables net generation...                          0.967043
# Plant annual total renewables net generation (MWh)                               NaN
# Plant total nonrenewables generation percent (r...                               NaN
# Plant total renewables generation percent (reso...                               NaN
# Ann CO2 Emissions Million Tons                                              0.974751
#
#                                                     Plant annual CO2 total output emission rate (lb/MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                               0.022984
# Plant longitude                                                                             -0.023235
# Number of units                                                                              0.020447
# Number of generators                                                                         0.011302
# Flag indicating if the plant burned or generate...                                           0.009639
# Plant capacity factor                                                                       -0.158044
# Plant nameplate capacity (MW)                                                               -0.038126
# Nonbaseload Factor                                                                           0.130167
# Plant annual net generation (MWh)                                                           -0.065455
# Plant annual CO2 emissions (tons)                                                           -0.060865
# Plant annual CH4 emissions (lbs)                                                            -0.060540
# Plant annual CO2 total output emission rate (lb...                                           1.000000
# Plant annual CH4 total output emission rate (lb...                                           0.951703
# Plant unadjusted annual heat input from combust...                                          -0.068350
# Plant nominal heat rate (Btu/kWh)                                                            0.998206
# Plant annual total nonrenewables net generation...                                          -0.065455
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                              -0.060930
#
#                                                     Plant annual CH4 total output emission rate (lb/MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                               0.032479
# Plant longitude                                                                             -0.018180
# Number of units                                                                              0.015867
# Number of generators                                                                         0.014221
# Flag indicating if the plant burned or generate...                                          -0.030497
# Plant capacity factor                                                                       -0.138050
# Plant nameplate capacity (MW)                                                               -0.041832
# Nonbaseload Factor                                                                           0.108917
# Plant annual net generation (MWh)                                                           -0.067893
# Plant annual CO2 emissions (tons)                                                           -0.065609
# Plant annual CH4 emissions (lbs)                                                            -0.056887
# Plant annual CO2 total output emission rate (lb...                                           0.951703
# Plant annual CH4 total output emission rate (lb...                                           1.000000
# Plant unadjusted annual heat input from combust...                                          -0.072442
# Plant nominal heat rate (Btu/kWh)                                                            0.949908
# Plant annual total nonrenewables net generation...                                          -0.067893
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                              -0.065641
#
#                                                     Plant unadjusted annual heat input from combustion (MMBtu)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                              -0.228417
# Plant longitude                                                                              0.117574
# Number of units                                                                              0.143994
# Number of generators                                                                         0.306366
# Flag indicating if the plant burned or generate...                                          -0.025340
# Plant capacity factor                                                                        0.367304
# Plant nameplate capacity (MW)                                                                0.758117
# Nonbaseload Factor                                                                          -0.321257
# Plant annual net generation (MWh)                                                            0.981271
# Plant annual CO2 emissions (tons)                                                            0.980221
# Plant annual CH4 emissions (lbs)                                                             0.953328
# Plant annual CO2 total output emission rate (lb...                                          -0.068350
# Plant annual CH4 total output emission rate (lb...                                          -0.072442
# Plant unadjusted annual heat input from combust...                                           1.000000
# Plant nominal heat rate (Btu/kWh)                                                           -0.071860
# Plant annual total nonrenewables net generation...                                           0.981271
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                               0.980253
#
#                                                     Plant nominal heat rate (Btu/kWh)  \
# Data Year                                                                         NaN
# Plant latitude                                                               0.021707
# Plant longitude                                                             -0.033334
# Number of units                                                              0.012323
# Number of generators                                                         0.001422
# Flag indicating if the plant burned or generate...                           0.014806
# Plant capacity factor                                                       -0.142250
# Plant nameplate capacity (MW)                                               -0.044708
# Nonbaseload Factor                                                           0.113756
# Plant annual net generation (MWh)                                           -0.068990
# Plant annual CO2 emissions (tons)                                           -0.064875
# Plant annual CH4 emissions (lbs)                                            -0.065008
# Plant annual CO2 total output emission rate (lb...                           0.998206
# Plant annual CH4 total output emission rate (lb...                           0.949908
# Plant unadjusted annual heat input from combust...                          -0.071860
# Plant nominal heat rate (Btu/kWh)                                            1.000000
# Plant annual total nonrenewables net generation...                          -0.068990
# Plant annual total renewables net generation (MWh)                                NaN
# Plant total nonrenewables generation percent (r...                                NaN
# Plant total renewables generation percent (reso...                                NaN
# Ann CO2 Emissions Million Tons                                              -0.064935
#
#                                                     Plant annual total nonrenewables net generation (MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                              -0.202163
# Plant longitude                                                                              0.121955
# Number of units                                                                              0.111673
# Number of generators                                                                         0.291088
# Flag indicating if the plant burned or generate...                                          -0.016533
# Plant capacity factor                                                                        0.355616
# Plant nameplate capacity (MW)                                                                0.759671
# Nonbaseload Factor                                                                          -0.313770
# Plant annual net generation (MWh)                                                            1.000000
# Plant annual CO2 emissions (tons)                                                            0.989921
# Plant annual CH4 emissions (lbs)                                                             0.967043
# Plant annual CO2 total output emission rate (lb...                                          -0.065455
# Plant annual CH4 total output emission rate (lb...                                          -0.067893
# Plant unadjusted annual heat input from combust...                                           0.981271
# Plant nominal heat rate (Btu/kWh)                                                           -0.068990
# Plant annual total nonrenewables net generation...                                           1.000000
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                               0.989928
#
#                                                     Plant annual total renewables net generation (MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
#
#                                                     Plant total nonrenewables generation percent (resource mix)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
#
#                                                     Plant total renewables generation percent (resource mix)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
#
#                                                     Ann CO2 Emissions Million Tons
# Data Year                                                                      NaN
# Plant latitude                                                           -0.204540
# Plant longitude                                                           0.122080
# Number of units                                                           0.125649
# Number of generators                                                      0.308584
# Flag indicating if the plant burned or generate...                       -0.030738
# Plant capacity factor                                                     0.329751
# Plant nameplate capacity (MW)                                             0.785426
# Nonbaseload Factor                                                       -0.282161
# Plant annual net generation (MWh)                                         0.989928
# Plant annual CO2 emissions (tons)                                         0.999994
# Plant annual CH4 emissions (lbs)                                          0.974751
# Plant annual CO2 total output emission rate (lb...                       -0.060930
# Plant annual CH4 total output emission rate (lb...                       -0.065641
# Plant unadjusted annual heat input from combust...                        0.980253
# Plant nominal heat rate (Btu/kWh)                                        -0.064935
# Plant annual total nonrenewables net generation...                        0.989928
# Plant annual total renewables net generation (MWh)                             NaN
# Plant total nonrenewables generation percent (r...                             NaN
# Plant total renewables generation percent (reso...                             NaN
# Ann CO2 Emissions Million Tons                                            1.000000
#
# [21 rows x 21 columns]

# %%
dfCOAL.corr()
# Out:
#                                                     Data Year  Plant latitude  \
# Data Year                                                 NaN             NaN
# Plant latitude                                            NaN        1.000000
# Plant longitude                                           NaN       -0.363627
# Number of units                                           NaN        0.033542
# Number of generators                                      NaN       -0.005976
# Flag indicating if the plant burned or generate...        NaN       -0.000409
# Plant capacity factor                                     NaN        0.055835
# Plant nameplate capacity (MW)                             NaN       -0.334555
# Nonbaseload Factor                                        NaN       -0.042785
# Plant annual net generation (MWh)                         NaN       -0.228748
# Plant annual CO2 emissions (tons)                         NaN       -0.218670
# Plant annual CH4 emissions (lbs)                          NaN       -0.194545
# Plant annual CO2 total output emission rate (lb...        NaN        0.003083
# Plant annual CH4 total output emission rate (lb...        NaN        0.023231
# Plant unadjusted annual heat input from combust...        NaN       -0.225848
# Plant nominal heat rate (Btu/kWh)                         NaN       -0.017756
# Plant annual total nonrenewables net generation...        NaN       -0.228748
# Plant annual total renewables net generation (MWh)        NaN             NaN
# Plant total nonrenewables generation percent (r...        NaN             NaN
# Plant total renewables generation percent (reso...        NaN             NaN
# Ann CO2 Emissions Million Tons                            NaN       -0.218694
#
#                                                     Plant longitude  \
# Data Year                                                       NaN
# Plant latitude                                            -0.363627
# Plant longitude                                            1.000000
# Number of units                                            0.029315
# Number of generators                                       0.079566
# Flag indicating if the plant burned or generate...         0.106593
# Plant capacity factor                                     -0.241275
# Plant nameplate capacity (MW)                              0.155471
# Nonbaseload Factor                                         0.216901
# Plant annual net generation (MWh)                          0.028706
# Plant annual CO2 emissions (tons)                          0.010388
# Plant annual CH4 emissions (lbs)                           0.009929
# Plant annual CO2 total output emission rate (lb...        -0.023860
# Plant annual CH4 total output emission rate (lb...        -0.045092
# Plant unadjusted annual heat input from combust...         0.014818
# Plant nominal heat rate (Btu/kWh)                         -0.001719
# Plant annual total nonrenewables net generation...         0.028706
# Plant annual total renewables net generation (MWh)              NaN
# Plant total nonrenewables generation percent (r...              NaN
# Plant total renewables generation percent (reso...              NaN
# Ann CO2 Emissions Million Tons                             0.010408
#
#                                                     Number of units  \
# Data Year                                                       NaN
# Plant latitude                                             0.033542
# Plant longitude                                            0.029315
# Number of units                                            1.000000
# Number of generators                                       0.735232
# Flag indicating if the plant burned or generate...         0.001664
# Plant capacity factor                                     -0.173435
# Plant nameplate capacity (MW)                              0.366251
# Nonbaseload Factor                                         0.187726
# Plant annual net generation (MWh)                          0.217878
# Plant annual CO2 emissions (tons)                          0.193497
# Plant annual CH4 emissions (lbs)                           0.176357
# Plant annual CO2 total output emission rate (lb...        -0.155177
# Plant annual CH4 total output emission rate (lb...        -0.165635
# Plant unadjusted annual heat input from combust...         0.232765
# Plant nominal heat rate (Btu/kWh)                         -0.121742
# Plant annual total nonrenewables net generation...         0.217878
# Plant annual total renewables net generation (MWh)              NaN
# Plant total nonrenewables generation percent (r...              NaN
# Plant total renewables generation percent (reso...              NaN
# Ann CO2 Emissions Million Tons                             0.193534
#
#                                                     Number of generators  \
# Data Year                                                            NaN
# Plant latitude                                                 -0.005976
# Plant longitude                                                 0.079566
# Number of units                                                 0.735232
# Number of generators                                            1.000000
# Flag indicating if the plant burned or generate...             -0.095136
# Plant capacity factor                                          -0.291241
# Plant nameplate capacity (MW)                                   0.464609
# Nonbaseload Factor                                              0.313120
# Plant annual net generation (MWh)                               0.220417
# Plant annual CO2 emissions (tons)                               0.193774
# Plant annual CH4 emissions (lbs)                                0.163547
# Plant annual CO2 total output emission rate (lb...             -0.088136
# Plant annual CH4 total output emission rate (lb...             -0.105480
# Plant unadjusted annual heat input from combust...              0.221557
# Plant nominal heat rate (Btu/kWh)                              -0.050828
# Plant annual total nonrenewables net generation...              0.220417
# Plant annual total renewables net generation (MWh)                   NaN
# Plant total nonrenewables generation percent (r...                   NaN
# Plant total renewables generation percent (reso...                   NaN
# Ann CO2 Emissions Million Tons                                  0.193799
#
#                                                     Flag indicating if the plant burned or generated any amount of coal  \
# Data Year                                                                                         NaN
# Plant latitude                                                                              -0.000409
# Plant longitude                                                                              0.106593
# Number of units                                                                              0.001664
# Number of generators                                                                        -0.095136
# Flag indicating if the plant burned or generate...                                           1.000000
# Plant capacity factor                                                                       -0.039095
# Plant nameplate capacity (MW)                                                               -0.159341
# Nonbaseload Factor                                                                           0.044746
# Plant annual net generation (MWh)                                                           -0.133426
# Plant annual CO2 emissions (tons)                                                           -0.141067
# Plant annual CH4 emissions (lbs)                                                            -0.139260
# Plant annual CO2 total output emission rate (lb...                                          -0.214088
# Plant annual CH4 total output emission rate (lb...                                          -0.262409
# Plant unadjusted annual heat input from combust...                                          -0.130177
# Plant nominal heat rate (Btu/kWh)                                                           -0.152405
# Plant annual total nonrenewables net generation...                                          -0.133426
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                              -0.141126
#
#                                                     Plant capacity factor  \
# Data Year                                                             NaN
# Plant latitude                                                   0.055835
# Plant longitude                                                 -0.241275
# Number of units                                                 -0.173435
# Number of generators                                            -0.291241
# Flag indicating if the plant burned or generate...              -0.039095
# Plant capacity factor                                            1.000000
# Plant nameplate capacity (MW)                                    0.041859
# Nonbaseload Factor                                              -0.981491
# Plant annual net generation (MWh)                                0.435021
# Plant annual CO2 emissions (tons)                                0.442492
# Plant annual CH4 emissions (lbs)                                 0.443397
# Plant annual CO2 total output emission rate (lb...               0.036927
# Plant annual CH4 total output emission rate (lb...               0.056953
# Plant unadjusted annual heat input from combust...               0.442476
# Plant nominal heat rate (Btu/kWh)                               -0.008644
# Plant annual total nonrenewables net generation...               0.435021
# Plant annual total renewables net generation (MWh)                    NaN
# Plant total nonrenewables generation percent (r...                    NaN
# Plant total renewables generation percent (reso...                    NaN
# Ann CO2 Emissions Million Tons                                   0.442523
#
#                                                     Plant nameplate capacity (MW)  \
# Data Year                                                                     NaN
# Plant latitude                                                          -0.334555
# Plant longitude                                                          0.155471
# Number of units                                                          0.366251
# Number of generators                                                     0.464609
# Flag indicating if the plant burned or generate...                      -0.159341
# Plant capacity factor                                                    0.041859
# Plant nameplate capacity (MW)                                            1.000000
# Nonbaseload Factor                                                      -0.015250
# Plant annual net generation (MWh)                                        0.830618
# Plant annual CO2 emissions (tons)                                        0.818811
# Plant annual CH4 emissions (lbs)                                         0.796756
# Plant annual CO2 total output emission rate (lb...                      -0.041386
# Plant annual CH4 total output emission rate (lb...                      -0.020008
# Plant unadjusted annual heat input from combust...                       0.825933
# Plant nominal heat rate (Btu/kWh)                                       -0.034482
# Plant annual total nonrenewables net generation...                       0.830618
# Plant annual total renewables net generation (MWh)                            NaN
# Plant total nonrenewables generation percent (r...                            NaN
# Plant total renewables generation percent (reso...                            NaN
# Ann CO2 Emissions Million Tons                                           0.818817
#
#                                                     Nonbaseload Factor  \
# Data Year                                                          NaN
# Plant latitude                                               -0.042785
# Plant longitude                                               0.216901
# Number of units                                               0.187726
# Number of generators                                          0.313120
# Flag indicating if the plant burned or generate...            0.044746
# Plant capacity factor                                        -0.981491
# Plant nameplate capacity (MW)                                -0.015250
# Nonbaseload Factor                                            1.000000
# Plant annual net generation (MWh)                            -0.419587
# Plant annual CO2 emissions (tons)                            -0.427349
# Plant annual CH4 emissions (lbs)                             -0.430311
# Plant annual CO2 total output emission rate (lb...           -0.047345
# Plant annual CH4 total output emission rate (lb...           -0.063450
# Plant unadjusted annual heat input from combust...           -0.425276
# Plant nominal heat rate (Btu/kWh)                            -0.005793
# Plant annual total nonrenewables net generation...           -0.419587
# Plant annual total renewables net generation (MWh)                 NaN
# Plant total nonrenewables generation percent (r...                 NaN
# Plant total renewables generation percent (reso...                 NaN
# Ann CO2 Emissions Million Tons                               -0.427386
#
#                                                     Plant annual net generation (MWh)  \
# Data Year                                                                         NaN
# Plant latitude                                                              -0.228748
# Plant longitude                                                              0.028706
# Number of units                                                              0.217878
# Number of generators                                                         0.220417
# Flag indicating if the plant burned or generate...                          -0.133426
# Plant capacity factor                                                        0.435021
# Plant nameplate capacity (MW)                                                0.830618
# Nonbaseload Factor                                                          -0.419587
# Plant annual net generation (MWh)                                            1.000000
# Plant annual CO2 emissions (tons)                                            0.990712
# Plant annual CH4 emissions (lbs)                                             0.979482
# Plant annual CO2 total output emission rate (lb...                          -0.050553
# Plant annual CH4 total output emission rate (lb...                          -0.017316
# Plant unadjusted annual heat input from combust...                           0.994562
# Plant nominal heat rate (Btu/kWh)                                           -0.060704
# Plant annual total nonrenewables net generation...                           1.000000
# Plant annual total renewables net generation (MWh)                                NaN
# Plant total nonrenewables generation percent (r...                                NaN
# Plant total renewables generation percent (reso...                                NaN
# Ann CO2 Emissions Million Tons                                               0.990719
#
#                                                     ...  \
# Data Year                                           ...
# Plant latitude                                      ...
# Plant longitude                                     ...
# Number of units                                     ...
# Number of generators                                ...
# Flag indicating if the plant burned or generate...  ...
# Plant capacity factor                               ...
# Plant nameplate capacity (MW)                       ...
# Nonbaseload Factor                                  ...
# Plant annual net generation (MWh)                   ...
# Plant annual CO2 emissions (tons)                   ...
# Plant annual CH4 emissions (lbs)                    ...
# Plant annual CO2 total output emission rate (lb...  ...
# Plant annual CH4 total output emission rate (lb...  ...
# Plant unadjusted annual heat input from combust...  ...
# Plant nominal heat rate (Btu/kWh)                   ...
# Plant annual total nonrenewables net generation...  ...
# Plant annual total renewables net generation (MWh)  ...
# Plant total nonrenewables generation percent (r...  ...
# Plant total renewables generation percent (reso...  ...
# Ann CO2 Emissions Million Tons                      ...
#
#                                                     Plant annual CH4 emissions (lbs)  \
# Data Year                                                                        NaN
# Plant latitude                                                             -0.194545
# Plant longitude                                                             0.009929
# Number of units                                                             0.176357
# Number of generators                                                        0.163547
# Flag indicating if the plant burned or generate...                         -0.139260
# Plant capacity factor                                                       0.443397
# Plant nameplate capacity (MW)                                               0.796756
# Nonbaseload Factor                                                         -0.430311
# Plant annual net generation (MWh)                                           0.979482
# Plant annual CO2 emissions (tons)                                           0.991928
# Plant annual CH4 emissions (lbs)                                            1.000000
# Plant annual CO2 total output emission rate (lb...                         -0.020837
# Plant annual CH4 total output emission rate (lb...                          0.031111
# Plant unadjusted annual heat input from combust...                          0.982882
# Plant nominal heat rate (Btu/kWh)                                          -0.041650
# Plant annual total nonrenewables net generation...                          0.979482
# Plant annual total renewables net generation (MWh)                               NaN
# Plant total nonrenewables generation percent (r...                               NaN
# Plant total renewables generation percent (reso...                               NaN
# Ann CO2 Emissions Million Tons                                              0.991927
#
#                                                     Plant annual CO2 total output emission rate (lb/MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                               0.003083
# Plant longitude                                                                             -0.023860
# Number of units                                                                             -0.155177
# Number of generators                                                                        -0.088136
# Flag indicating if the plant burned or generate...                                          -0.214088
# Plant capacity factor                                                                        0.036927
# Plant nameplate capacity (MW)                                                               -0.041386
# Nonbaseload Factor                                                                          -0.047345
# Plant annual net generation (MWh)                                                           -0.050553
# Plant annual CO2 emissions (tons)                                                           -0.023768
# Plant annual CH4 emissions (lbs)                                                            -0.020837
# Plant annual CO2 total output emission rate (lb...                                           1.000000
# Plant annual CH4 total output emission rate (lb...                                           0.970536
# Plant unadjusted annual heat input from combust...                                          -0.047030
# Plant nominal heat rate (Btu/kWh)                                                            0.986840
# Plant annual total nonrenewables net generation...                                          -0.050553
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                              -0.023796
#
#                                                     Plant annual CH4 total output emission rate (lb/MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                               0.023231
# Plant longitude                                                                             -0.045092
# Number of units                                                                             -0.165635
# Number of generators                                                                        -0.105480
# Flag indicating if the plant burned or generate...                                          -0.262409
# Plant capacity factor                                                                        0.056953
# Plant nameplate capacity (MW)                                                               -0.020008
# Nonbaseload Factor                                                                          -0.063450
# Plant annual net generation (MWh)                                                           -0.017316
# Plant annual CO2 emissions (tons)                                                            0.011238
# Plant annual CH4 emissions (lbs)                                                             0.031111
# Plant annual CO2 total output emission rate (lb...                                           0.970536
# Plant annual CH4 total output emission rate (lb...                                           1.000000
# Plant unadjusted annual heat input from combust...                                          -0.016163
# Plant nominal heat rate (Btu/kWh)                                                            0.939167
# Plant annual total nonrenewables net generation...                                          -0.017316
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                               0.011218
#
#                                                     Plant unadjusted annual heat input from combustion (MMBtu)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                              -0.225848
# Plant longitude                                                                              0.014818
# Number of units                                                                              0.232765
# Number of generators                                                                         0.221557
# Flag indicating if the plant burned or generate...                                          -0.130177
# Plant capacity factor                                                                        0.442476
# Plant nameplate capacity (MW)                                                                0.825933
# Nonbaseload Factor                                                                          -0.425276
# Plant annual net generation (MWh)                                                            0.994562
# Plant annual CO2 emissions (tons)                                                            0.995489
# Plant annual CH4 emissions (lbs)                                                             0.982882
# Plant annual CO2 total output emission rate (lb...                                          -0.047030
# Plant annual CH4 total output emission rate (lb...                                          -0.016163
# Plant unadjusted annual heat input from combust...                                           1.000000
# Plant nominal heat rate (Btu/kWh)                                                           -0.058549
# Plant annual total nonrenewables net generation...                                           0.994562
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                               0.995494
#
#                                                     Plant nominal heat rate (Btu/kWh)  \
# Data Year                                                                         NaN
# Plant latitude                                                              -0.017756
# Plant longitude                                                             -0.001719
# Number of units                                                             -0.121742
# Number of generators                                                        -0.050828
# Flag indicating if the plant burned or generate...                          -0.152405
# Plant capacity factor                                                       -0.008644
# Plant nameplate capacity (MW)                                               -0.034482
# Nonbaseload Factor                                                          -0.005793
# Plant annual net generation (MWh)                                           -0.060704
# Plant annual CO2 emissions (tons)                                           -0.040013
# Plant annual CH4 emissions (lbs)                                            -0.041650
# Plant annual CO2 total output emission rate (lb...                           0.986840
# Plant annual CH4 total output emission rate (lb...                           0.939167
# Plant unadjusted annual heat input from combust...                          -0.058549
# Plant nominal heat rate (Btu/kWh)                                            1.000000
# Plant annual total nonrenewables net generation...                          -0.060704
# Plant annual total renewables net generation (MWh)                                NaN
# Plant total nonrenewables generation percent (r...                                NaN
# Plant total renewables generation percent (reso...                                NaN
# Ann CO2 Emissions Million Tons                                              -0.040054
#
#                                                     Plant annual total nonrenewables net generation (MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                              -0.228748
# Plant longitude                                                                              0.028706
# Number of units                                                                              0.217878
# Number of generators                                                                         0.220417
# Flag indicating if the plant burned or generate...                                          -0.133426
# Plant capacity factor                                                                        0.435021
# Plant nameplate capacity (MW)                                                                0.830618
# Nonbaseload Factor                                                                          -0.419587
# Plant annual net generation (MWh)                                                            1.000000
# Plant annual CO2 emissions (tons)                                                            0.990712
# Plant annual CH4 emissions (lbs)                                                             0.979482
# Plant annual CO2 total output emission rate (lb...                                          -0.050553
# Plant annual CH4 total output emission rate (lb...                                          -0.017316
# Plant unadjusted annual heat input from combust...                                           0.994562
# Plant nominal heat rate (Btu/kWh)                                                           -0.060704
# Plant annual total nonrenewables net generation...                                           1.000000
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                               0.990719
#
#                                                     Plant annual total renewables net generation (MWh)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
#
#                                                     Plant total nonrenewables generation percent (resource mix)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
#
#                                                     Plant total renewables generation percent (resource mix)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
#
#                                                     Ann CO2 Emissions Million Tons
# Data Year                                                                      NaN
# Plant latitude                                                           -0.218694
# Plant longitude                                                           0.010408
# Number of units                                                           0.193534
# Number of generators                                                      0.193799
# Flag indicating if the plant burned or generate...                       -0.141126
# Plant capacity factor                                                     0.442523
# Plant nameplate capacity (MW)                                             0.818817
# Nonbaseload Factor                                                       -0.427386
# Plant annual net generation (MWh)                                         0.990719
# Plant annual CO2 emissions (tons)                                         1.000000
# Plant annual CH4 emissions (lbs)                                          0.991927
# Plant annual CO2 total output emission rate (lb...                       -0.023796
# Plant annual CH4 total output emission rate (lb...                        0.011218
# Plant unadjusted annual heat input from combust...                        0.995494
# Plant nominal heat rate (Btu/kWh)                                        -0.040054
# Plant annual total nonrenewables net generation...                        0.990719
# Plant annual total renewables net generation (MWh)                             NaN
# Plant total nonrenewables generation percent (r...                             NaN
# Plant total renewables generation percent (reso...                             NaN
# Ann CO2 Emissions Million Tons                                            1.000000
#
# [21 rows x 21 columns]

# %%
#How much does Methane emission rise with CO2 Emission for Coal and Natural Gas.  Are the ratios different?

sns.regplot('Plant annual CO2 emissions (tons)', 'Plant annual CH4 emissions (lbs)', data=dfGAS)

# %%
sns.regplot('Plant annual CO2 emissions (tons)', 'Plant annual CH4 emissions (lbs)', data=dfCOAL, color='red', marker = 'o')

# %%
#Now I'm going to make a multiple regression including 'Plant unadjusted annual heat input from combustion (MMBtu)' to see if I can make the model more accurate.

X = dfCOAL[['Plant annual net generation (MWh)','Plant unadjusted annual heat input from combustion (MMBtu)']]

# %%
X = sm.add_constant(X)

# %%
y = dfCOAL[['Ann CO2 Emissions Million Tons']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
# Create the model
rModel3 = sm.OLS(y_train,X_train)

# Fit the model with fit() 
rModel3_results = rModel3.fit()

# %%
print(rModel3_results.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     Ann CO2 Emissions Million Tons   R-squared:                       0.991
# Model:                                        OLS   Adj. R-squared:                  0.991
# Method:                             Least Squares   F-statistic:                 1.240e+04
# Date:                            Wed, 05 Aug 2020   Prob (F-statistic):          3.67e-238
# Time:                                    16:01:24   Log-Likelihood:                -122.02
# No. Observations:                             237   AIC:                             250.0
# Df Residuals:                                 234   BIC:                             260.4
# Df Model:                                       2
# Covariance Type:                        nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.0771      0.040     -1.947      0.053      -0.155       0.001
# Plant annual net generation (MWh)                            1.01e-07   6.43e-08      1.572      0.117   -2.56e-08    2.28e-07
# Plant unadjusted annual heat input from combustion (MMBtu)  9.366e-08   6.34e-09     14.771      0.000    8.12e-08    1.06e-07
# ==============================================================================
# Omnibus:                      249.316   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6555.561
# Skew:                          -4.398   Prob(JB):                         0.00
# Kurtosis:                      27.217   Cond. No.                     8.54e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.54e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#This produces an even higher R-squared.  Wow!

# %% [markdown]
# # Chapter 4:  Null hypothesis Testing
#
# Finally I decided to do some null hypothesis testing.  First to test the null hypothesis that Gas CO2 emissions were the same as Coal CO2 emissions.  Then to test the null hypothesis that fuel source didn't make a difference in CO2 emissions for Coal plants.
#
# Then as I realized that that fuel source for Coal was driving a difference in emissions, I added dummy variables for the fuel sources and added this to the regression.  This created ultimately the model that I would use as an output of this project to predict CO2 output for Coal plants.

# %%
#This command turns a dataframe into a numpy 1D array:

coaltest = dfCOAL['Plant annual CO2 total output emission rate (lb/MWh)'].values.ravel()
gastest = dfGAS['Plant annual CO2 total output emission rate (lb/MWh)'].values.ravel()

# %%
coalnew = np.random.choice(coaltest,100, replace = False)
gasnew = np.random.choice(gastest,100, replace = False)

# %%
def permutation_sample(data1, data2):
    """Generate a permutation sample from two data sets."""

    # Concatenate the data sets: data
    data = np.concatenate((data1, data2))

    # Permute the concatenated array: permuted_data
    permuted_data = np.random.permutation(data)

    # Split the permuted array into two: perm_sample_1, perm_sample_2
    perm_sample_1 = permuted_data[:len(data1)]
    perm_sample_2 = permuted_data[len(data1):]

    return perm_sample_1, perm_sample_2

# %%
def draw_perm_reps(data_1, data_2, func, size=1):
    """Generate multiple permutation replicates."""

    # Initialize array of replicates: perm_replicates
    perm_replicates = np.empty(size)

    for i in range(size):
        # Generate permutation sample
        perm_sample_1, perm_sample_2 = permutation_sample(data_1, data_2)

        # Compute the test statistic
        perm_replicates[i] = func(perm_sample_1, perm_sample_2)

    return perm_replicates

# %%
# I want to test the null hypothesis the CO2 Emissions for Natural Gas are the same as for Coal.  I already know the answer, but I will do this to test my null hypothesis testing.  I'll use the 'Plant annual CO2 total output emission rate (lb/MWh)' metric to test this.
#Plant annual CO2 total output emission rate (lb/MWh)

def diff_of_means(data_1, data_2):
    """Difference in means of two arrays."""

    # The difference of means of data_1, data_2: diff
    diff = np.mean(data_1) - np.mean(data_2)

    return diff

# %%
coalvgas = diff_of_means(coalnew, gasnew)

# %%
perm_replicates = draw_perm_reps(coalnew, gasnew,diff_of_means, size=10000)

# Compute p-value: p
p = np.sum(perm_replicates >= coalvgas) / len(perm_replicates)

# Print the result
print('p-value =', p)
# Out:
# p-value = 0.0

# %%
#We can clearly reject the null hypotheses that the mean Coal CO2 emission rate is the same as the mean Gas CO2 emission rate.

# %%
#Within coal there seems to be a difference between the emissions depending on the type of fuel also. 
sns.lmplot(x='Plant annual net generation (MWh)', y='Ann CO2 Emissions Million Tons', data=dfCOAL, hue='Plant primary fuel',palette='Set1')

# %%
dfCOAL['Plant primary fuel'].value_counts()
# Out:
# SUB    124
# BIT    111
# RC      42
# WC      17
# LIG     15
# COG      6
# SGC      1
# Name: Plant primary fuel, dtype: int64

# %%
#I will make the null hypothesis that SUB and BIT Fuel types produce the same emissions

# %%
SUB = dfCOAL[dfCOAL['Plant primary fuel']=='SUB']

# %%
SUB = SUB['Plant annual CO2 total output emission rate (lb/MWh)'].values.ravel()

# %%
BIT = dfCOAL[dfCOAL['Plant primary fuel']=='BIT']

# %%
BIT = BIT['Plant annual CO2 total output emission rate (lb/MWh)'].values.ravel()

# %%
SUBvsBIT = diff_of_means(SUB, BIT)

print(SUBvsBIT)
# Out:
# 256.5660242662025

# %%
perm_replicates2 = draw_perm_reps(SUB, BIT, diff_of_means, size=10000)

# %%
# Compute p-value: p
p = np.sum(perm_replicates2 >= SUBvsBIT) / len(perm_replicates2)

# Print the result
print('p-value =', p)
# Out:
# p-value = 0.0189

# %%
#This also shows that using the SUB vs the BIT fuel source leads to significantly different results in CO2 emissions.

# %%
#The last step to do is to use categorical variables (e.g. Plant Primary Fuel) also as part of the Regression to see if I can further improve it.

# %%
dfCOAL = pd.concat([dfCOAL, pd.get_dummies(df['Plant primary fuel'])], axis=1).drop(['Plant primary fuel'], axis =1)

# %%
dfCOAL.fillna(0, inplace=True)

# %%
dfCOAL.corr()
# Out:
#                                                     Data Year  Plant latitude  \
# Data Year                                            1.000000        0.988843
# Plant latitude                                       0.988843        1.000000
# Plant longitude                                     -0.988273       -0.985518
# Number of units                                      0.796243        0.790382
# Number of generators                                 0.786950        0.777621
# Flag indicating if the plant burned or generate...   0.987741        0.976712
# Plant capacity factor                                0.858396        0.853085
# Plant nameplate capacity (MW)                        0.710681        0.667692
# Nonbaseload Factor                                   0.864318        0.851470
# Plant annual net generation (MWh)                    0.646580        0.613372
# Plant annual CO2 emissions (tons)                    0.654387        0.622456
# Plant annual CH4 emissions (lbs)                     0.645403        0.616067
# Plant annual CO2 total output emission rate (lb...   0.872129        0.862623
# Plant annual CH4 total output emission rate (lb...   0.858401        0.850600
# Plant unadjusted annual heat input from combust...   0.666812        0.634301
# Plant nominal heat rate (Btu/kWh)                    0.884316        0.873215
# Plant annual total nonrenewables net generation...   0.646580        0.613372
# Plant annual total renewables net generation (MWh)        NaN             NaN
# Plant total nonrenewables generation percent (r...   1.000000        0.988843
# Plant total renewables generation percent (reso...        NaN             NaN
# Ann CO2 Emissions Million Tons                       0.654377        0.622442
# BIT                                                  0.556861        0.529052
# COG                                                  0.125748        0.124002
# LIG                                                  0.199309        0.199845
# NG                                                  -1.000000       -0.988843
# RC                                                   0.335976        0.337134
# SGC                                                  0.051267        0.049914
# SUB                                                  0.590767        0.597313
# WC                                                   0.212296        0.219393
#
#                                                     Plant longitude  \
# Data Year                                                 -0.988273
# Plant latitude                                            -0.985518
# Plant longitude                                            1.000000
# Number of units                                           -0.784198
# Number of generators                                      -0.770226
# Flag indicating if the plant burned or generate...        -0.973618
# Plant capacity factor                                     -0.867229
# Plant nameplate capacity (MW)                             -0.685646
# Nonbaseload Factor                                        -0.837525
# Plant annual net generation (MWh)                         -0.635654
# Plant annual CO2 emissions (tons)                         -0.645514
# Plant annual CH4 emissions (lbs)                          -0.636677
# Plant annual CO2 total output emission rate (lb...        -0.863684
# Plant annual CH4 total output emission rate (lb...        -0.851867
# Plant unadjusted annual heat input from combust...        -0.657306
# Plant nominal heat rate (Btu/kWh)                         -0.874069
# Plant annual total nonrenewables net generation...        -0.635654
# Plant annual total renewables net generation (MWh)              NaN
# Plant total nonrenewables generation percent (r...        -0.988273
# Plant total renewables generation percent (reso...              NaN
# Ann CO2 Emissions Million Tons                            -0.645501
# BIT                                                       -0.504605
# COG                                                       -0.109725
# LIG                                                       -0.224439
# NG                                                         0.988273
# RC                                                        -0.330029
# SGC                                                       -0.047932
# SUB                                                       -0.632841
# WC                                                        -0.181839
#
#                                                     Number of units  \
# Data Year                                                  0.796243
# Plant latitude                                             0.790382
# Plant longitude                                           -0.784198
# Number of units                                            1.000000
# Number of generators                                       0.901052
# Flag indicating if the plant burned or generate...         0.786640
# Plant capacity factor                                      0.629667
# Plant nameplate capacity (MW)                              0.721755
# Nonbaseload Factor                                         0.745327
# Plant annual net generation (MWh)                          0.615387
# Plant annual CO2 emissions (tons)                          0.609568
# Plant annual CH4 emissions (lbs)                           0.595394
# Plant annual CO2 total output emission rate (lb...         0.648494
# Plant annual CH4 total output emission rate (lb...         0.632093
# Plant unadjusted annual heat input from combust...         0.635885
# Plant nominal heat rate (Btu/kWh)                          0.669744
# Plant annual total nonrenewables net generation...         0.615387
# Plant annual total renewables net generation (MWh)              NaN
# Plant total nonrenewables generation percent (r...         0.796243
# Plant total renewables generation percent (reso...              NaN
# Ann CO2 Emissions Million Tons                             0.609578
# BIT                                                        0.513430
# COG                                                        0.100036
# LIG                                                        0.088884
# NG                                                        -0.796243
# RC                                                         0.242923
# SGC                                                        0.026332
# SUB                                                        0.482329
# WC                                                         0.071018
#
#                                                     Number of generators  \
# Data Year                                                       0.786950
# Plant latitude                                                  0.777621
# Plant longitude                                                -0.770226
# Number of units                                                 0.901052
# Number of generators                                            1.000000
# Flag indicating if the plant burned or generate...              0.768140
# Plant capacity factor                                           0.583330
# Plant nameplate capacity (MW)                                   0.760948
# Nonbaseload Factor                                              0.777345
# Plant annual net generation (MWh)                               0.612574
# Plant annual CO2 emissions (tons)                               0.605378
# Plant annual CH4 emissions (lbs)                                0.584981
# Plant annual CO2 total output emission rate (lb...              0.659714
# Plant annual CH4 total output emission rate (lb...              0.642133
# Plant unadjusted annual heat input from combust...              0.626623
# Plant nominal heat rate (Btu/kWh)                               0.681271
# Plant annual total nonrenewables net generation...              0.612574
# Plant annual total renewables net generation (MWh)                   NaN
# Plant total nonrenewables generation percent (r...              0.786950
# Plant total renewables generation percent (reso...                   NaN
# Ann CO2 Emissions Million Tons                                  0.605383
# BIT                                                             0.517082
# COG                                                             0.032556
# LIG                                                             0.098102
# NG                                                             -0.786950
# RC                                                              0.270633
# SGC                                                             0.077864
# SUB                                                             0.469075
# WC                                                              0.035734
#
#                                                     Flag indicating if the plant burned or generated any amount of coal  \
# Data Year                                                                                    0.987741
# Plant latitude                                                                               0.976712
# Plant longitude                                                                             -0.973618
# Number of units                                                                              0.786640
# Number of generators                                                                         0.768140
# Flag indicating if the plant burned or generate...                                           1.000000
# Plant capacity factor                                                                        0.844742
# Plant nameplate capacity (MW)                                                                0.684471
# Nonbaseload Factor                                                                           0.857236
# Plant annual net generation (MWh)                                                            0.622765
# Plant annual CO2 emissions (tons)                                                            0.629714
# Plant annual CH4 emissions (lbs)                                                             0.620887
# Plant annual CO2 total output emission rate (lb...                                           0.845086
# Plant annual CH4 total output emission rate (lb...                                           0.826866
# Plant unadjusted annual heat input from combust...                                           0.643494
# Plant nominal heat rate (Btu/kWh)                                                            0.862368
# Plant annual total nonrenewables net generation...                                           0.622765
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                           0.987741
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                               0.629697
# BIT                                                                                          0.541515
# COG                                                                                          0.267348
# LIG                                                                                          0.191726
# NG                                                                                          -0.987741
# RC                                                                                           0.323193
# SGC                                                                                          0.049317
# SUB                                                                                          0.568291
# WC                                                                                           0.204219
#
#                                                     Plant capacity factor  \
# Data Year                                                        0.858396
# Plant latitude                                                   0.853085
# Plant longitude                                                 -0.867229
# Number of units                                                  0.629667
# Number of generators                                             0.583330
# Flag indicating if the plant burned or generate...               0.844742
# Plant capacity factor                                            1.000000
# Plant nameplate capacity (MW)                                    0.625152
# Nonbaseload Factor                                               0.488697
# Plant annual net generation (MWh)                                0.725259
# Plant annual CO2 emissions (tons)                                0.733366
# Plant annual CH4 emissions (lbs)                                 0.727753
# Plant annual CO2 total output emission rate (lb...               0.757900
# Plant annual CH4 total output emission rate (lb...               0.751835
# Plant unadjusted annual heat input from combust...               0.741543
# Plant nominal heat rate (Btu/kWh)                                0.757023
# Plant annual total nonrenewables net generation...               0.725259
# Plant annual total renewables net generation (MWh)                    NaN
# Plant total nonrenewables generation percent (r...               0.858396
# Plant total renewables generation percent (reso...                    NaN
# Ann CO2 Emissions Million Tons                                   0.733371
# BIT                                                              0.369268
# COG                                                              0.089879
# LIG                                                              0.158889
# NG                                                              -0.858396
# RC                                                               0.354059
# SGC                                                              0.051879
# SUB                                                              0.540089
# WC                                                               0.284281
#
#                                                     Plant nameplate capacity (MW)  \
# Data Year                                                                0.710681
# Plant latitude                                                           0.667692
# Plant longitude                                                         -0.685646
# Number of units                                                          0.721755
# Number of generators                                                     0.760948
# Flag indicating if the plant burned or generate...                       0.684471
# Plant capacity factor                                                    0.625152
# Plant nameplate capacity (MW)                                            1.000000
# Nonbaseload Factor                                                       0.608859
# Plant annual net generation (MWh)                                        0.905283
# Plant annual CO2 emissions (tons)                                        0.900643
# Plant annual CH4 emissions (lbs)                                         0.886831
# Plant annual CO2 total output emission rate (lb...                       0.605560
# Plant annual CH4 total output emission rate (lb...                       0.602829
# Plant unadjusted annual heat input from combust...                       0.906909
# Plant nominal heat rate (Btu/kWh)                                        0.617141
# Plant annual total nonrenewables net generation...                       0.905283
# Plant annual total renewables net generation (MWh)                            NaN
# Plant total nonrenewables generation percent (r...                       0.710681
# Plant total renewables generation percent (reso...                            NaN
# Ann CO2 Emissions Million Tons                                           0.900644
# BIT                                                                      0.460895
# COG                                                                     -0.014833
# LIG                                                                      0.119094
# NG                                                                      -0.710681
# RC                                                                       0.332674
# SGC                                                                      0.034371
# SUB                                                                      0.395180
# WC                                                                      -0.009437
#
#                                                     Nonbaseload Factor  \
# Data Year                                                     0.864318
# Plant latitude                                                0.851470
# Plant longitude                                              -0.837525
# Number of units                                               0.745327
# Number of generators                                          0.777345
# Flag indicating if the plant burned or generate...            0.857236
# Plant capacity factor                                         0.488697
# Plant nameplate capacity (MW)                                 0.608859
# Nonbaseload Factor                                            1.000000
# Plant annual net generation (MWh)                             0.397868
# Plant annual CO2 emissions (tons)                             0.403075
# Plant annual CH4 emissions (lbs)                              0.392521
# Plant annual CO2 total output emission rate (lb...            0.742146
# Plant annual CH4 total output emission rate (lb...            0.725562
# Plant unadjusted annual heat input from combust...            0.416940
# Plant nominal heat rate (Btu/kWh)                             0.762970
# Plant annual total nonrenewables net generation...            0.397868
# Plant annual total renewables net generation (MWh)                 NaN
# Plant total nonrenewables generation percent (r...            0.864318
# Plant total renewables generation percent (reso...                 NaN
# Ann CO2 Emissions Million Tons                                0.403050
# BIT                                                           0.578723
# COG                                                           0.127658
# LIG                                                           0.183960
# NG                                                           -0.864318
# RC                                                            0.228025
# SGC                                                           0.038257
# SUB                                                           0.487137
# WC                                                            0.079057
#
#                                                     Plant annual net generation (MWh)  \
# Data Year                                                                    0.646580
# Plant latitude                                                               0.613372
# Plant longitude                                                             -0.635654
# Number of units                                                              0.615387
# Number of generators                                                         0.612574
# Flag indicating if the plant burned or generate...                           0.622765
# Plant capacity factor                                                        0.725259
# Plant nameplate capacity (MW)                                                0.905283
# Nonbaseload Factor                                                           0.397868
# Plant annual net generation (MWh)                                            1.000000
# Plant annual CO2 emissions (tons)                                            0.994590
# Plant annual CH4 emissions (lbs)                                             0.988043
# Plant annual CO2 total output emission rate (lb...                           0.545032
# Plant annual CH4 total output emission rate (lb...                           0.548249
# Plant unadjusted annual heat input from combust...                           0.996549
# Plant nominal heat rate (Btu/kWh)                                            0.550161
# Plant annual total nonrenewables net generation...                           1.000000
# Plant annual total renewables net generation (MWh)                                NaN
# Plant total nonrenewables generation percent (r...                           0.646580
# Plant total renewables generation percent (reso...                                NaN
# Ann CO2 Emissions Million Tons                                               0.994594
# BIT                                                                          0.367421
# COG                                                                         -0.012927
# LIG                                                                          0.108908
# NG                                                                          -0.646580
# RC                                                                           0.347523
# SGC                                                                          0.036041
# SUB                                                                          0.379688
# WC                                                                          -0.004255
#
#                                                     ...  \
# Data Year                                           ...
# Plant latitude                                      ...
# Plant longitude                                     ...
# Number of units                                     ...
# Number of generators                                ...
# Flag indicating if the plant burned or generate...  ...
# Plant capacity factor                               ...
# Plant nameplate capacity (MW)                       ...
# Nonbaseload Factor                                  ...
# Plant annual net generation (MWh)                   ...
# Plant annual CO2 emissions (tons)                   ...
# Plant annual CH4 emissions (lbs)                    ...
# Plant annual CO2 total output emission rate (lb...  ...
# Plant annual CH4 total output emission rate (lb...  ...
# Plant unadjusted annual heat input from combust...  ...
# Plant nominal heat rate (Btu/kWh)                   ...
# Plant annual total nonrenewables net generation...  ...
# Plant annual total renewables net generation (MWh)  ...
# Plant total nonrenewables generation percent (r...  ...
# Plant total renewables generation percent (reso...  ...
# Ann CO2 Emissions Million Tons                      ...
# BIT                                                 ...
# COG                                                 ...
# LIG                                                 ...
# NG                                                  ...
# RC                                                  ...
# SGC                                                 ...
# SUB                                                 ...
# WC                                                  ...
#
#                                                     Plant total renewables generation percent (resource mix)  \
# Data Year                                                                                         NaN
# Plant latitude                                                                                    NaN
# Plant longitude                                                                                   NaN
# Number of units                                                                                   NaN
# Number of generators                                                                              NaN
# Flag indicating if the plant burned or generate...                                                NaN
# Plant capacity factor                                                                             NaN
# Plant nameplate capacity (MW)                                                                     NaN
# Nonbaseload Factor                                                                                NaN
# Plant annual net generation (MWh)                                                                 NaN
# Plant annual CO2 emissions (tons)                                                                 NaN
# Plant annual CH4 emissions (lbs)                                                                  NaN
# Plant annual CO2 total output emission rate (lb...                                                NaN
# Plant annual CH4 total output emission rate (lb...                                                NaN
# Plant unadjusted annual heat input from combust...                                                NaN
# Plant nominal heat rate (Btu/kWh)                                                                 NaN
# Plant annual total nonrenewables net generation...                                                NaN
# Plant annual total renewables net generation (MWh)                                                NaN
# Plant total nonrenewables generation percent (r...                                                NaN
# Plant total renewables generation percent (reso...                                                NaN
# Ann CO2 Emissions Million Tons                                                                    NaN
# BIT                                                                                               NaN
# COG                                                                                               NaN
# LIG                                                                                               NaN
# NG                                                                                                NaN
# RC                                                                                                NaN
# SGC                                                                                               NaN
# SUB                                                                                               NaN
# WC                                                                                                NaN
#
#                                                     Ann CO2 Emissions Million Tons  \
# Data Year                                                                 0.654377
# Plant latitude                                                            0.622442
# Plant longitude                                                          -0.645501
# Number of units                                                           0.609578
# Number of generators                                                      0.605383
# Flag indicating if the plant burned or generate...                        0.629697
# Plant capacity factor                                                     0.733371
# Plant nameplate capacity (MW)                                             0.900644
# Nonbaseload Factor                                                        0.403050
# Plant annual net generation (MWh)                                         0.994594
# Plant annual CO2 emissions (tons)                                         1.000000
# Plant annual CH4 emissions (lbs)                                          0.995267
# Plant annual CO2 total output emission rate (lb...                        0.561897
# Plant annual CH4 total output emission rate (lb...                        0.566069
# Plant unadjusted annual heat input from combust...                        0.997324
# Plant nominal heat rate (Btu/kWh)                                         0.564535
# Plant annual total nonrenewables net generation...                        0.994594
# Plant annual total renewables net generation (MWh)                             NaN
# Plant total nonrenewables generation percent (r...                        0.654377
# Plant total renewables generation percent (reso...                             NaN
# Ann CO2 Emissions Million Tons                                            1.000000
# BIT                                                                       0.354087
# COG                                                                      -0.015811
# LIG                                                                       0.122164
# NG                                                                       -0.654377
# RC                                                                        0.355224
# SGC                                                                       0.027500
# SUB                                                                       0.393762
# WC                                                                        0.002131
#
#                                                          BIT       COG  \
# Data Year                                           0.556861  0.125748
# Plant latitude                                      0.529052  0.124002
# Plant longitude                                    -0.504605 -0.109725
# Number of units                                     0.513430  0.100036
# Number of generators                                0.517082  0.032556
# Flag indicating if the plant burned or generate...  0.541515  0.267348
# Plant capacity factor                               0.369268  0.089879
# Plant nameplate capacity (MW)                       0.460895 -0.014833
# Nonbaseload Factor                                  0.578723  0.127658
# Plant annual net generation (MWh)                   0.367421 -0.012927
# Plant annual CO2 emissions (tons)                   0.354092 -0.015776
# Plant annual CH4 emissions (lbs)                    0.347389 -0.016427
# Plant annual CO2 total output emission rate (lb...  0.448129  0.013674
# Plant annual CH4 total output emission rate (lb...  0.442464 -0.015456
# Plant unadjusted annual heat input from combust...  0.372797 -0.006134
# Plant nominal heat rate (Btu/kWh)                   0.471256  0.046978
# Plant annual total nonrenewables net generation...  0.367421 -0.012927
# Plant annual total renewables net generation (MWh)       NaN       NaN
# Plant total nonrenewables generation percent (r...  0.556861  0.125748
# Plant total renewables generation percent (reso...       NaN       NaN
# Ann CO2 Emissions Million Tons                      0.354087 -0.015811
# BIT                                                 1.000000 -0.014331
# COG                                                -0.014331  1.000000
# LIG                                                -0.022715 -0.005129
# NG                                                 -0.556861 -0.125748
# RC                                                 -0.038291 -0.008647
# SGC                                                -0.005843 -0.001319
# SUB                                                -0.067329 -0.015204
# WC                                                 -0.024195 -0.005464
#
#                                                          LIG        NG  \
# Data Year                                           0.199309 -1.000000
# Plant latitude                                      0.199845 -0.988843
# Plant longitude                                    -0.224439  0.988273
# Number of units                                     0.088884 -0.796243
# Number of generators                                0.098102 -0.786950
# Flag indicating if the plant burned or generate...  0.191726 -0.987741
# Plant capacity factor                               0.158889 -0.858396
# Plant nameplate capacity (MW)                       0.119094 -0.710681
# Nonbaseload Factor                                  0.183960 -0.864318
# Plant annual net generation (MWh)                   0.108908 -0.646580
# Plant annual CO2 emissions (tons)                   0.122175 -0.654387
# Plant annual CH4 emissions (lbs)                    0.122153 -0.645403
# Plant annual CO2 total output emission rate (lb...  0.183028 -0.872129
# Plant annual CH4 total output emission rate (lb...  0.184312 -0.858401
# Plant unadjusted annual heat input from combust...  0.114596 -0.666812
# Plant nominal heat rate (Btu/kWh)                   0.175121 -0.884316
# Plant annual total nonrenewables net generation...  0.108908 -0.646580
# Plant annual total renewables net generation (MWh)       NaN       NaN
# Plant total nonrenewables generation percent (r...  0.199309 -1.000000
# Plant total renewables generation percent (reso...       NaN       NaN
# Ann CO2 Emissions Million Tons                      0.122164 -0.654377
# BIT                                                -0.022715 -0.556861
# COG                                                -0.005129 -0.125748
# LIG                                                 1.000000 -0.199309
# NG                                                 -0.199309  1.000000
# RC                                                 -0.013705 -0.335976
# SGC                                                -0.002091 -0.051267
# SUB                                                -0.024098 -0.590767
# WC                                                 -0.008660 -0.212296
#
#                                                           RC       SGC  \
# Data Year                                           0.335976  0.051267
# Plant latitude                                      0.337134  0.049914
# Plant longitude                                    -0.330029 -0.047932
# Number of units                                     0.242923  0.026332
# Number of generators                                0.270633  0.077864
# Flag indicating if the plant burned or generate...  0.323193  0.049317
# Plant capacity factor                               0.354059  0.051879
# Plant nameplate capacity (MW)                       0.332674  0.034371
# Nonbaseload Factor                                  0.228025  0.038257
# Plant annual net generation (MWh)                   0.347523  0.036041
# Plant annual CO2 emissions (tons)                   0.355200  0.027467
# Plant annual CH4 emissions (lbs)                    0.360850  0.005866
# Plant annual CO2 total output emission rate (lb...  0.285843  0.032330
# Plant annual CH4 total output emission rate (lb...  0.297018  0.006576
# Plant unadjusted annual heat input from combust...  0.353332  0.023152
# Plant nominal heat rate (Btu/kWh)                   0.284039  0.027571
# Plant annual total nonrenewables net generation...  0.347523  0.036041
# Plant annual total renewables net generation (MWh)       NaN       NaN
# Plant total nonrenewables generation percent (r...  0.335976  0.051267
# Plant total renewables generation percent (reso...       NaN       NaN
# Ann CO2 Emissions Million Tons                      0.355224  0.027500
# BIT                                                -0.038291 -0.005843
# COG                                                -0.008647 -0.001319
# LIG                                                -0.013705 -0.002091
# NG                                                 -0.335976 -0.051267
# RC                                                  1.000000 -0.003525
# SGC                                                -0.003525  1.000000
# SUB                                                -0.040622 -0.006199
# WC                                                 -0.014598 -0.002228
#
#                                                          SUB        WC
# Data Year                                           0.590767  0.212296
# Plant latitude                                      0.597313  0.219393
# Plant longitude                                    -0.632841 -0.181839
# Number of units                                     0.482329  0.071018
# Number of generators                                0.469075  0.035734
# Flag indicating if the plant burned or generate...  0.568291  0.204219
# Plant capacity factor                               0.540089  0.284281
# Plant nameplate capacity (MW)                       0.395180 -0.009437
# Nonbaseload Factor                                  0.487137  0.079057
# Plant annual net generation (MWh)                   0.379688 -0.004255
# Plant annual CO2 emissions (tons)                   0.393784  0.002120
# Plant annual CH4 emissions (lbs)                    0.386030  0.000525
# Plant annual CO2 total output emission rate (lb...  0.546731  0.258733
# Plant annual CH4 total output emission rate (lb...  0.543183  0.232944
# Plant unadjusted annual heat input from combust...  0.396525  0.002744
# Plant nominal heat rate (Btu/kWh)                   0.546695  0.240916
# Plant annual total nonrenewables net generation...  0.379688 -0.004255
# Plant annual total renewables net generation (MWh)       NaN       NaN
# Plant total nonrenewables generation percent (r...  0.590767  0.212296
# Plant total renewables generation percent (reso...       NaN       NaN
# Ann CO2 Emissions Million Tons                      0.393762  0.002131
# BIT                                                -0.067329 -0.024195
# COG                                                -0.015204 -0.005464
# LIG                                                -0.024098 -0.008660
# NG                                                 -0.590767 -0.212296
# RC                                                 -0.040622 -0.014598
# SGC                                                -0.006199 -0.002228
# SUB                                                 1.000000 -0.025668
# WC                                                 -0.025668  1.000000
#
# [29 rows x 29 columns]

# %%
#Now I'm going to make a multiple regression including 'Plant unadjusted annual heat input from combustion (MMBtu)' to see if I can make the model more accurate.

X = dfCOAL[['Plant annual net generation (MWh)','Plant unadjusted annual heat input from combustion (MMBtu)', 'BIT','COG','LIG','NG','RC','SGC','SUB','WC']]

# %%
X = sm.add_constant(X)

# %%
y = dfCOAL[['Ann CO2 Emissions Million Tons']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
# Create the model
rModel4 = sm.OLS(y_train,X_train)

# Fit the model with fit() 
rModel4_results = rModel4.fit()

# %%
#This is my most accurate model for predicting CO2 Emissions from COAL with an R2 of .997.

print(rModel4_results.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     Ann CO2 Emissions Million Tons   R-squared:                       0.997
# Model:                                        OLS   Adj. R-squared:                  0.997
# Method:                             Least Squares   F-statistic:                 5.065e+04
# Date:                            Wed, 05 Aug 2020   Prob (F-statistic):               0.00
# Time:                                    16:01:28   Log-Likelihood:                 928.35
# No. Observations:                            1395   AIC:                            -1837.
# Df Residuals:                                1385   BIC:                            -1784.
# Df Model:                                       9
# Covariance Type:                        nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.0229      0.017     -1.324      0.186      -0.057       0.011
# Plant annual net generation (MWh)                          -1.065e-07   2.17e-08     -4.901      0.000   -1.49e-07   -6.38e-08
# Plant unadjusted annual heat input from combustion (MMBtu)   1.14e-07   2.11e-09     53.946      0.000     1.1e-07    1.18e-07
# BIT                                                           -0.1629      0.021     -7.819      0.000      -0.204      -0.122
# COG                                                           -0.3798      0.052     -7.242      0.000      -0.483      -0.277
# LIG                                                            0.1453      0.034      4.267      0.000       0.079       0.212
# NG                                                             0.0229      0.018      1.301      0.193      -0.012       0.057
# RC                                                            -0.0671      0.028     -2.428      0.015      -0.121      -0.013
# SGC                                                            0.5336      0.114      4.679      0.000       0.310       0.757
# SUB                                                           -0.0662      0.021     -3.136      0.002      -0.108      -0.025
# WC                                                            -0.0487      0.036     -1.341      0.180      -0.120       0.023
# ==============================================================================
# Omnibus:                     2014.653   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           699646.497
# Skew:                          -8.242   Prob(JB):                         0.00
# Kurtosis:                     111.467   Cond. No.                     1.68e+22
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.61e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Let's use our new model to make predictions of the dependent variable y. Use predict(), and plug in X_test as the parameter
y_pred = rModel4_results.predict(X_test)

# %%
# Plot the predictions
# Build a scatterplot
plt.scatter(y_test, y_pred)

# Add a line for perfect correlation. Can you see what this line is doing? Use plot()
plt.plot([x for x in range(0,15)],[x for x in range(0,15)], color='red')

# Label it nicely
plt.title("Model 2 predictions vs. the actual values")
plt.xlabel("Energy Created - COAL, Fuel Source, Btus")
plt.ylabel("CO2 Generated - COAL")
# Out:
# Text(0, 0.5, 'CO2 Generated - COAL')

# %%
# Define a function to check the RMSE. Remember the def keyword needed to make functions? 
from math import sqrt

def RMSE(y_actual, y_predicted):
    return sqrt(mean_squared_error(y_actual, y_predicted))
    
'''OR
    def rmse(predictions, targets):
        return np.sqrt(((predictions - targets) ** 2).mean())'''
# Out:
# 'OR\n    def rmse(predictions, targets):\n        return np.sqrt(((predictions - targets) ** 2).mean())'

# %%
# Get predictions from rModel4



# Put the predictions & actual values into a dataframe

matches = pd.DataFrame(y_test)
matches.rename(columns = {'Ann CO2 Emissions Million Tons':'actual'}, inplace=True)
matches["predicted"] = y_pred

RMSE(matches["actual"], matches["predicted"])
# Out:
# 0.2415467752363869
